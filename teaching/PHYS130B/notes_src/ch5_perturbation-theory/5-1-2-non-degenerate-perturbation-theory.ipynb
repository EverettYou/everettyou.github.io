# %% [markdown]
# # 5.1.2 Non-Degenerate Perturbation Theory

# %% [markdown]
# :::{admonition} Prompts
# :class: tip
#
# - If you know only $\hat{H}_0$ and $V_{mn}=\langle m|\hat V|n\rangle$, what is the algorithm to build $E_n(\lambda)$ and $|n(\lambda)\rangle$ order by order?
# - Why do the two Hellmann-Feynman identities naturally split into an "energy equation" ($m=n$) and a "state-mixing equation" ($m\neq n$)?
# - How do coupling strength $V_{mn}$ and level spacing $E_n-E_m$ control hybridization and convergence?
# - Why does near-degeneracy make the non-degenerate formulas diverge, and what is the right next step physically?
# :::

# %% [markdown]
# ## Lecture Notes
#
# ### Overview
#
# In Sec. 5.1.1 we solved a qubit model exactly and expanded the answer in powers of $\lambda$. Here we derive the same type of expansion **without exact diagonalization**, using only the unperturbed spectrum of $\hat H_0$ and matrix elements of $\hat V$.
#
# Our route is straightforward:
#
# 1. write the parameterized eigenproblem,
# 2. derive derivative identities (Hellmann-Feynman),
# 3. convert derivatives into perturbative corrections,
# 4. interpret physically (hybridization, level repulsion, breakdown near degeneracy).
#
# ### Problem Setup
#
# The general perturbative setup $\hat H(\lambda)=\hat H_0+\lambda\hat V$ and its toy-model motivation were introduced in Sec. 5.1.1. Here we add only the extra assumption needed for this subsection:
#
# $$
# E_n\neq E_m\quad (n\neq m),
# $$
#
# so each index $n$ labels a unique unperturbed eigenstate of
#
# $$
# \hat H_0|n\rangle=E_n|n\rangle.
# $$
#
# Under this non-degeneracy condition, we can use matrix elements
#
# $$
# V_{mn}=\langle m|\hat V|n\rangle
# $$
#
# to build $E_n(\lambda)$ and $|n(\lambda)\rangle$ order by order.
#
# :::{admonition} Notation Rule
# :class: note
#
# When no explicit $(\lambda)$ is shown, quantities are evaluated at $\lambda=0$.
# :::
#
# ### Hellmann-Feynman Identities (Core Engine)
#
# Differentiate the eigen-equation and project with $\langle m|$:
#
# $$
# \langle m|\hat V|n\rangle = \partial_\lambda E_n\,\delta_{mn} + (E_n-E_m)\langle m|\partial_\lambda n\rangle.
# $$
#
# This immediately gives two key identities:
#
# - **(m=n): first Hellmann-Feynman**
#
# $$
# \partial_\lambda E_n = V_{nn}
# $$
#
# - **(m\neq n): second Hellmann-Feynman**
#
# $$
# \langle m|\partial_\lambda n\rangle = \frac{V_{mn}}{E_n-E_m}.
# $$
#
# The second equation is the origin of coupling-over-gap behavior.
#
# ### Energy Corrections
#
# Use Taylor expansion
#
# $$
# E_n(\lambda)=E_n+\lambda E_n^{(1)}+\lambda^2E_n^{(2)}+\cdots.
# $$
#
# :::{admonition} Results up to second order
# :class: important
#
# $$
# E_n^{(1)}=V_{nn}=\langle n|\hat V|n\rangle,
# $$
#
# $$
# E_n^{(2)}=\sum_{m\neq n}\frac{|V_{mn}|^2}{E_n-E_m}.
# $$
# :::
#
# :::{admonition} Poll: sign of ground-state shift
# :class: dropdown poll
#
# For a non-degenerate ground state $n=0$, what is the sign of
# $E_0^{(2)}=\sum_{m\neq 0}\frac{|V_{m0}|^2}{E_0-E_m}$?
#
# (A) always positive
#
# (B) always negative
#
# (C) either sign
#
# (D) always zero
# :::
#
# ### State Corrections
#
# Similarly,
#
# $$
# |n(\lambda)\rangle = |n\rangle + \lambda |n^{(1)}\rangle + \cdots.
# $$
#
# From the second Hellmann-Feynman identity,
#
# :::{admonition} First-order state correction
# :class: important
#
# $$
# |n^{(1)}\rangle = \sum_{m\neq n}|m\rangle\frac{V_{mn}}{E_n-E_m}.
# $$
# :::
#
# Interpretation: state $|n\rangle$ hybridizes with nearby levels; large coupling and small energy gap produce stronger mixing.
#
# ### Physical Intuition and Validity
#
# - **Diagonal matrix elements** $V_{nn}$ shift energies at first order.
# - **Off-diagonal matrix elements** $V_{mn}$ mix states and generate second-order shifts.
# - **Level repulsion**: virtual transitions push levels apart.
# - **Breakdown criterion**: if $|E_n-E_m|$ becomes comparable to $|V_{mn}|$, denominators become large and non-degenerate perturbation theory loses validity.
#
# Then we must switch to **degenerate perturbation theory** (Sec. 5.1.3).
#
# :::{admonition} Example: check against the qubit toy model
# :class: dropdown example
#
# For $\hat H=\hat Z+\lambda \hat X$ with $E_+=+1$, $E_-=-1$ and $V_{++}=V_{--}=0$:
#
# $$
# E_+^{(1)}=0,
# $$
#
# $$
# E_+^{(2)}=\frac{|\langle -|\hat X|+\rangle|^2}{E_+-E_-}=\frac{1}{2},
# $$
#
# so
#
# $$
# E_+(\lambda)=1+\frac{\lambda^2}{2}+\cdots,
# $$
#
# consistent with
#
# $$
# \sqrt{1+\lambda^2}=1+\frac{\lambda^2}{2}-\frac{\lambda^4}{8}+\cdots.
# $$
#
# Also,
#
# $$
# |+^{(1)}\rangle = \frac{1}{2}|-\rangle,
# $$
#
# which matches the exact eigenvector expansion at small $\lambda$.
# :::
#
# :::{admonition} Discussion: what does divergence mean?
# :class: dropdown tip
#
# When $E_n-E_m\to 0$, formulas like $V_{mn}/(E_n-E_m)$ diverge. Is this a physical singularity, or a sign that our basis choice is no longer appropriate? Explain how block-diagonalization inside the nearly degenerate subspace resolves this issue.
# :::
#
# ### Summary
#
# - Non-degenerate perturbation theory is an **iterative derivative algorithm** built from Hellmann-Feynman identities.
# - First-order energy comes from diagonal matrix elements: $E_n^{(1)}=V_{nn}$.
# - First-order state mixing is coupling over gap: $|n^{(1)}\rangle=\sum_{m\neq n}|m\rangle V_{mn}/(E_n-E_m)$.
# - Second-order energy is a sum over virtual processes: $E_n^{(2)}=\sum_{m\neq n}|V_{mn}|^2/(E_n-E_m)$.
# - Near degeneracy is not a failure of QM; it signals a change of method (degenerate perturbation theory).
#
# :::{admonition} See Also
# :class: seealso
#
# - [5.1.1 Toy Model](5-1-1-toy-model): exact qubit solution and small-$\lambda$ expansion
# - [5.1.3 Degenerate Perturbation Theory](5-1-3-degenerate-perturbation-theory): block treatment near resonance
# :::

# %% [markdown]
# ## Homework
#
# The problems are ordered to follow the lecture algorithm: setup and identities $\to$ corrections $\to$ physical interpretation and breakdown.
#
# **1. Gauge choice and normalization convention.** Starting from $\langle n(\lambda)|n(\lambda)\rangle=1$, show that one can choose the phase convention so that
#
# $$
# \langle n^{(0)}|n^{(1)}\rangle=0.
# $$
#
# Explain why this choice simplifies perturbative state corrections.
#
# **2. Hellmann-Feynman as the engine.** For
#
# $$
# \hat H(\lambda)=\hat H_0+\lambda \hat V,
# $$
#
# $$
# \hat H(\lambda)|n(\lambda)\rangle=E_n(\lambda)|n(\lambda)\rangle,
# $$
#
# (a) Derive
#
# $$
# \langle m|\hat V|n\rangle=\partial_\lambda E_n\,\delta_{mn}+(E_n-E_m)\langle m|\partial_\lambda n\rangle.
# $$
#
# (b) Specialize to $m=n$ and recover $E_n^{(1)}=V_{nn}$.
#
# (c) Specialize to $m\neq n$ and recover
#
# $$
# \langle m|\partial_\lambda n\rangle=\frac{V_{mn}}{E_n-E_m}.
# $$
#
# **3. First-order state correction.** Use Problem 2 and completeness to show
#
# $$
# |n^{(1)}\rangle=\sum_{m\neq n}|m\rangle\frac{V_{mn}}{E_n-E_m}.
# $$
#
# Then explain physically why this coefficient scales as coupling/gap.
#
# **4. Second-order energy correction and sign.** Starting from
#
# $$
# E_n^{(2)}=\sum_{m\neq n}\frac{|V_{mn}|^2}{E_n-E_m},
# $$
#
# (a) show $E_0^{(2)}\le 0$ for the non-degenerate ground state,
#
# (b) interpret the result as level repulsion,
#
# (c) connect it to the variational principle.
#
# **5. Toy-model consistency check (from Sec. 5.1.1).** For $\hat H=\hat Z+\lambda \hat X$:
#
# (a) compute $E_\pm^{(1)}$ and $E_\pm^{(2)}$ by perturbation theory,
#
# (b) compute $|\pm^{(1)}\rangle$,
#
# (c) compare with the exact expansion of $E_\pm(\lambda)=\pm\sqrt{1+\lambda^2}$ and comment on agreement order-by-order.
#
# **6. Harmonic oscillator with linear perturbation.** Let
#
# $$
# \hat H_0=\hbar\omega\left(a^\dagger a+\frac12\right),
# $$
#
# $$
# \hat V=\lambda x,
# $$
#
# $$
# x=\sqrt{\frac{\hbar}{2m\omega}}(a+a^\dagger).
# $$
#
# (a) Compute $V_{nn}$, $V_{n+1,n}$, $V_{n-1,n}$.
#
# (b) Use non-degenerate perturbation theory to obtain $E_n$ up to second order.
#
# (c) Solve the full Hamiltonian by completing the square and compare with perturbation theory.
#
# **7. Selection rules and parity.** For a 1D parity-symmetric potential with odd perturbation $V=\lambda x$:
#
# (a) show $E_n^{(1)}=0$ for all $n$,
#
# (b) identify which matrix elements contribute to $E_n^{(2)}$,
#
# (c) explain how symmetry controls which virtual transitions are allowed.
#
# **8. Near-degeneracy and breakdown.** A 3-level system has unperturbed energies $E_1=0$, $E_2=\Delta$, $E_3=10\Delta$, with nonzero couplings $V_{12}$ and $V_{23}$.
#
# (a) Write $E_1^{(2)}$ explicitly.
#
# (b) Analyze $\Delta\to 0$ and identify which term causes the breakdown.
#
# (c) Give the correct next-step method (basis choice and effective subspace treatment) instead of applying non-degenerate formulas blindly.
