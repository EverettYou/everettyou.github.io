# %% [markdown]
# # 5.2.3 Applications

# %% [markdown]
# :::{admonition} Prompts
# :class: tip
#
# - Across driven dynamics, spectroscopy, decay, and transport, what common quantity does first-order time-dependent perturbation theory compute?
# - For harmonic driving, what sets the resonance condition and the oscillation scale in a two-level approximation?
# - In light-matter coupling, why do dipole selection rules follow from symmetry properties of the interaction operator?
# - How does Fermi's golden rule connect matrix elements and density of states to measurable lifetime and natural linewidth?
# - In linear response, why can weak electromagnetic driving be written as current coupling to a vector potential, and how does this connect to Hall conductance quantization for filled Landau levels?
# :::

# %% [markdown]
# ## Lecture Notes
#
# ### Overview
#
# The core method is unchanged: use first-order time-dependent perturbation theory to compute transition amplitudes, then interpret the result in different physical settings.
#
# This subsection follows one clean thread:
# 1. **Driven two-level dynamics** (resonance and Rabi oscillations),
# 2. **Atomic transitions** (dipole matrix elements and selection rules),
# 3. **Continuum final states** (golden-rule rate, lifetime, linewidth),
# 4. **Many-body response** (Kubo formula and quantized Hall conductance).
#
# The key lecture idea is that one perturbative formalism supports both spectroscopy and transport.
#
# ### Application 1: Harmonic Driving and Resonance
#
# Consider a monochromatic perturbation
#
# $$
# V(t)=V_0\cos(\omega t)=\frac{V_0}{2}\left(\mathrm{e}^{\mathrm{i}\omega t}+\mathrm{e}^{-\mathrm{i}\omega t}\right).
# $$
#
# For a transition $|i\rangle\to|f\rangle$ with $\omega_{fi}=(E_f-E_i)/\hbar$, first-order amplitudes contain denominators $(\omega-\omega_{fi})$ and $(\omega+\omega_{fi})$. Near resonance $\omega\approx\omega_{fi}$, the resonant term dominates (rotating-wave approximation).
#
# :::{admonition} Resonance and Rabi scale
# :class: important
#
# Near resonance in an effective two-level description,
#
# $$
# P_{i\to f}(t)=\sin^2\!\left(\frac{\Omega_R t}{2}\right),\qquad
# \Omega_R=\frac{|V_{fi}|}{\hbar}.
# $$
#
# So spectroscopy reads off level spacings from resonance positions, while coherent control uses pulse area ($\pi$ pulse, $\pi/2$ pulse, etc.).
# :::
#
# ### Application 2: Electric Dipole Transitions and Selection Rules
#
# For light-matter coupling in the dipole approximation,
#
# $$
# V(t)=-\boldsymbol{d}\cdot\boldsymbol{E}(t)=e\,\boldsymbol{r}\cdot\boldsymbol{E}(t),
# $$
#
# so transition strength is controlled by $\langle f|\boldsymbol{r}|i\rangle$.
#
# :::{admonition} Dipole selection rules (single-electron atom)
# :class: note
#
# For $n\ell m_\ell\to n'\ell' m_\ell'$:
# - $\Delta \ell=\pm1$,
# - $\Delta m_\ell=0,\pm1$ (polarization dependent),
# - $\Delta S=0$ in non-relativistic electric-dipole transitions.
#
# Hence some channels are strongly allowed while others are suppressed (metastable states).
# :::
#
# ### Application 3: Golden Rule, Lifetime, and Linewidth
#
# When a discrete initial state couples to many final states, first-order perturbation theory gives a transition **rate** rather than coherent oscillation:
#
# $$
# \Gamma=\frac{2\pi}{\hbar}\sum_f|\langle f|V|i\rangle|^2\delta(E_f-E_i).
# $$
#
# This is Fermi's golden rule. The same quantity sets spectroscopic broadening.
#
# :::{admonition} Lifetime-linewidth link
# :class: important
#
# $$
# \tau=\frac{1}{\Gamma},\qquad \Delta E\sim\hbar\Gamma=\frac{\hbar}{\tau}.
# $$
#
# Finite lifetime implies a Lorentzian line with intrinsic (natural) width.
# :::
#
# :::{admonition} Poll: one formalism, two regimes
# :class: dropdown poll
#
# Which statement best distinguishes the resonance (Rabi) and golden-rule regimes?
#
# (A) Rabi oscillations require exact degeneracy; golden rule requires no coupling.
#
# (B) Rabi describes coherent dynamics among a few levels; golden rule describes irreversible-looking transfer into many final states.
#
# (C) Golden rule is non-perturbative, while Rabi is perturbative.
#
# (D) They use different Hamiltonians and are unrelated.
# :::
#
# ### Application 4: Linear Response and Kubo Formula
#
# Now apply the same perturbative logic to transport. For a weak uniform electric field,
#
# $$
# \boldsymbol{E}(t)=\boldsymbol{E}\,\mathrm{e}^{-\mathrm{i}(\omega+\mathrm{i}0^+)t},
# $$
#
# introduce
#
# $$
# \delta\boldsymbol{A}(t)=\frac{\mathrm{i}\boldsymbol{E}}{\omega+\mathrm{i}0^+}\,\mathrm{e}^{-\mathrm{i}(\omega+\mathrm{i}0^+)t},
# \qquad \boldsymbol{E}(t)=-\partial_t\delta\boldsymbol{A}(t),
# $$
#
# and from minimal coupling obtain
#
# $$
# \delta\hat{H}(t)=-\hat{\boldsymbol{j}}\cdot\delta\boldsymbol{A}(t).
# $$ (eq-kubo-perturbation)
#
# First-order response of current to this perturbation gives the Hall conductivity.
#
# :::{admonition} Kubo formula (zero temperature)
# :class: important
#
# $$
# \sigma_{xy}=\frac{\mathrm{i}\hbar}{A}
# \sum_{\alpha\in\mathrm{occ}}\sum_{\beta\notin\mathrm{occ}}
# \frac{\langle\alpha|\hat{j}_x|\beta\rangle\langle\beta|\hat{j}_y|\alpha\rangle-
# \langle\alpha|\hat{j}_y|\beta\rangle\langle\beta|\hat{j}_x|\alpha\rangle}
# {(E_\beta-E_\alpha)^2}.
# $$ (eq-kubo-hall-523)
#
# It is a matrix-element form of linear response: transport coefficients are fixed by virtual transitions between occupied and empty states.
# :::
#
# Evaluating this formula for $\nu$ completely filled Landau levels gives
#
# $$
# \sigma_{xy}=\nu\frac{e^2}{h},
# $$
#
# connecting perturbation theory to an exact quantized observable (details in §4.3.3).
#
# ### Summary
#
# - One perturbative framework generates four experimentally central ideas: resonance, selection rules, decay rates, and transport coefficients.
# - Harmonic driving emphasizes **coherent** transitions and Rabi control.
# - Coupling to many final states gives **rates** (golden rule), hence lifetime and linewidth.
# - Linear response uses the same first-order logic with $\delta\hat{H}=-\hat{\boldsymbol{j}}\cdot\delta\boldsymbol{A}$, yielding the Kubo formula.
# - For integer-filled Landau levels, Kubo evaluation gives exact Hall quantization $\sigma_{xy}=\nu e^2/h$.
#
# :::{admonition} See Also
# :class: seealso
#
# - [5.2.2 Fermi's Golden Rule](5-2-2-fermis-golden-rule): Transition rates and resonance window used in lifetime/linewidth analysis.
# - [5.2.1 Interaction Picture](5-2-1-interaction-picture): Dyson expansion and first-order amplitudes underlying all applications here.
# - [4.3.3 Quantum Hall Effect](../ch4_phase-and-gauge/4-3-3-quantum-hall-effect): Explicit Landau-level evaluation of Kubo formula and quantized $\sigma_{xy}$.
# :::

# %% [markdown]
# ## Homework
#
# **1. Resonance estimate.** A two-level system has $\omega_{01}=1.0\times10^{15}\,\mathrm{rad/s}$ and is driven by $V(t)=V_0\cos(\omega t)$ with on-resonance matrix element $|V_{01}|=0.10\,\mathrm{meV}$.
#
# (a) Compute $\Omega_R=|V_{01}|/\hbar$.
#
# (b) Find the $\pi$-pulse time.
#
# (c) If the pulse length is half of that value, what is the excitation probability?
#
# **2. Detuning and maximum transfer.** Let $\delta=\omega-\omega_{01}=0.1\,\Omega_R$.
#
# (a) Write the rotating-frame two-level Hamiltonian.
#
# (b) Compute $\Omega'=\sqrt{\Omega_R^2+\delta^2}$.
#
# (c) Show that the maximum transition probability is $(\Omega_R/\Omega')^2<1$ and interpret physically.
#
# **3. Dipole selection-rule check.** Decide whether each electric-dipole transition is allowed, and state which rule decides:
#
# (a) $1s\to 2s$.
#
# (b) $2p,m=1\to 1s,m=0$ with right-circularly polarized light.
#
# (c) $3d\to 2s$.
#
# **4. Linewidth from a measured rate.** A spectroscopic transition has decay rate $\Gamma=6.2\times 10^8\,\mathrm{s}^{-1}$.
#
# (a) Compute the natural linewidth $\Delta E$ in eV.
#
# (b) An experiment resolves features 100× narrower than $\Delta E$. Explain in one sentence what that says about the experiment's sensitivity to lifetime broadening.
#
# **5. Minimal Kubo exercise (toy model).** Let $\hat{H}_0=-\frac12\hbar\omega_0\hat{Z}$ with occupied $\vert 0\rangle$, empty $\vert 1\rangle$. As a structural exercise, take $\hat{j}_x=\hat{X}$ and $\hat{j}_y=\hat{Y}$ (without charge or geometry prefactors — the goal is the antisymmetric matrix-element structure, not a physical conductivity).
#
# (a) Compute the four matrix elements entering the Kubo numerator.
#
# (b) Evaluate
#
# $$
# \sigma_{xy}=\mathrm{i}\hbar
# \frac{\langle 0\vert\hat{j}_x\vert 1\rangle\langle 1\vert\hat{j}_y\vert 0\rangle-
# \langle 0\vert\hat{j}_y\vert 1\rangle\langle 1\vert\hat{j}_x\vert 0\rangle}
# {(E_1-E_0)^2}.
# $$
#
# (c) Replace $\hat{j}_y\to\hat{X}$ and show why $\sigma_{xy}$ vanishes — i.e., why a Hall response requires *non-commuting* current operators.
#
# **6. Three rates, one framework.** For each setting below, identify (i) which matrix element sets the rate, (ii) the role of final-state density (or its absence), and (iii) the directly measured experimental observable. Write a single-line expression for the rate or response coefficient (prefactors not required).
#
# (a) Coherent Rabi inversion at resonance with drive amplitude $\Omega_R$.
#
# (b) Spontaneous emission of an excited atomic state into the photon vacuum.
#
# (c) Hall conductivity $\sigma_{xy}$ at zero temperature for a two-band insulator.
