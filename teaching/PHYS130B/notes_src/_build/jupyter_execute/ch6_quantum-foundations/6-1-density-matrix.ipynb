# %% [markdown]
# # 6.1 Density Matrix

# %% [markdown]
# ## Overview
#
# Until now, we have described quantum states as **vectors** $|\psi\rangle$ in Hilbert space. This works perfectly for **pure states**—states with complete, maximal information.
#
# However, quantum mechanics also deals with **mixed states**: states arising from incomplete knowledge, entanglement with an inaccessible environment, or decoherence. For these cases, a single state vector is insufficient. The **density matrix** formalism provides the general framework to describe all quantum states, pure and mixed alike.
#
# ### Lessons
#
# ```{list-table}
# :header-rows: 1
# :widths: 8 35 57
#
# * - Lesson
#   - Title
#   - Keywords
# * - 6.1.1
#   - [Mixed States](6-1-1-mixed-states)
#   - density operator, pure vs mixed, Bloch ball
# * - 6.1.2
#   - [Partial Trace](6-1-2-partial-trace)
#   - partial trace, reduced density matrix, subsystem state
# * - 6.1.3
#   - [Entropy](6-1-3-entropy)
#   - von Neumann entropy, entanglement entropy, information
# ```
#
# ### Key Concepts
#
# - **Density matrix**: The most general description of a quantum state, $\rho = \sum_i p_i |\psi_i\rangle\langle\psi_i|$, satisfying $\rho^\dagger = \rho$, $\rho \geq 0$, and $\text{Tr}(\rho) = 1$.
#
# - **Pure vs. mixed states**: A state is pure if $\text{Tr}(\rho^2) = 1$ (equivalently, $\rho = |\psi\rangle\langle\psi|$ for some $|\psi\rangle$), and mixed if $\text{Tr}(\rho^2) < 1$. Mixed states cannot be represented by a single state vector.
#
# - **Partial trace**: Given a composite system $\rho_{AB}$, the reduced density matrix $\rho_A = \text{Tr}_B(\rho_{AB})$ describes subsystem $A$ alone. If the full state is entangled, $\rho_A$ is necessarily mixed.
#
# - **Von Neumann entropy**: $S(\rho) = -\text{Tr}(\rho \ln \rho)$. Vanishes for pure states and is maximized for the maximally mixed state $\rho = I/d$. For bipartite pure states, $S(\rho_A)$ quantifies entanglement.
#
# - **Bloch ball**: While pure qubit states live on the Bloch sphere ($|\hat{n}| = 1$), mixed qubit states correspond to points inside the ball ($|\hat{n}| < 1$), with the maximally mixed state $\rho = I/2$ at the center.
#
# ### Learning Objectives
#
# - Construct the density matrix representation for both pure and mixed quantum states and verify properties of Hermiticity, positivity, and trace normalization.
# - Compute the purity $\text{Tr}(\rho^2)$ and distinguish between pure and mixed states using spectral decomposition.
# - Apply the partial trace operation to extract the reduced density matrix of a subsystem and explain how entanglement produces mixed reduced states.
# - Calculate the von Neumann entropy and use it to quantify information content and entanglement in quantum systems.

# %% [markdown]
# ## Projects
#
# ### Classical Shadow Tomography: Efficient Quantum State Estimation
#
# **Objective:** Study the classical shadow protocol (Huang et al., 2020) for estimating exponentially many properties of a quantum state using only O(log M) random measurements. Implement the protocol for a few-qubit system and compare its efficiency to full state tomography.
#
# **Background:** Full quantum state tomography requires exponentially many measurements in the number of qubits. The classical shadow protocol revolutionizes this by using random Clifford unitaries and classical post-processing to efficiently estimate expectation values. This is one of the major breakthroughs in quantum information science in the past decade.
#
# **Suggested Approach:**
# 1. **Literature Survey:** Read Huang et al. (arXiv:2011.02993) and understand: (a) random Clifford sampling, (b) classical snapshot construction, (c) median-of-means post-processing for robust estimation.
# 2. **Implementation:** Write Python code to:
#    - Generate random Clifford circuits for 2-3 qubits
#    - Simulate measurement outcomes
#    - Reconstruct classical shadow estimates
#    - Compute expectation values of observables
# 3. **Comparison:** For a known 2-3 qubit state:
#    - Estimate observables using classical shadows
#    - Compare to full state tomography
#    - Measure sample complexity and computational cost as a function of system size
# 4. **Extension:** Explore robustness to noise and realistic measurement errors.
#
# **Expected Deliverable:**
# - Code implementing classical shadow protocol
# - Numerical comparison: shadows vs. tomography (accuracy vs. sample count)
# - Brief scientific summary (1-2 pages) explaining why classical shadows are more efficient than tomography and when they should be preferred in practice.
#
# **Frontier Aspect:** This is an active research frontier. Understanding shadows opens doors to applications in quantum error correction, entanglement detection, and quantum machine learning.
