# %% [markdown]
# # 1.1.2 State and Representation

# %% [markdown]
# :::{admonition} Prompts
# :class: tip
#
# - What is a quantum state? How does the abstract ket $\vert \psi\rangle$ relate to its vector representation $(\alpha, \beta)$ in a particular basis?
# - Why does a qubit state require only two real parameters ($\theta, \phi$) when we started with four real numbers from two complex amplitudes?
# - What is Born's rule? Why is global phase unobservable — what stays the same if we multiply a state by $\mathrm{e}^{\mathrm{i}\gamma}$?
# - The Bloch sphere maps each qubit state to a point on a 2-sphere. How do the X, Y, and Z bases appear geometrically? What does the Bloch vector $\boldsymbol{n}$ represent physically?
# :::

# %% [markdown]
# ## Lecture Notes
#
# ### Overview
#
# Quantum mechanics assigns to each physical system a **state vector** $\vert \psi\rangle$ that encodes all information necessary to predict measurement outcomes. This section develops the mathematical language—kets, bras, inner products, and orthonormal bases—then introduces the **qubit** as the simplest concrete example, and arrives at the **Bloch sphere** as its geometric picture.
#
# ### Ket, Bra, and Inner Product
#
# **Ket notation** represents a quantum state as an abstract vector in a complex Hilbert space. For a two-level system (qubit), the state lives in $\mathcal{H} = \mathbb{C}^2$.
#
# :::{admonition} Definition: Ket and Bra
# :class: important
#
# - The **ket** $\vert \psi\rangle$ is an abstract vector in Hilbert space.
# - The **bra** $\langle \psi\vert $ is the dual (Hermitian conjugate) of the ket: $\langle \psi\vert = (\vert \psi\rangle)^\dagger$.
# - The **inner product** (scalar product) $\langle\phi\vert \psi\rangle$ is a complex number satisfying:
#
# $$
#
# \langle\phi\vert \psi\rangle = \langle\psi\vert \phi\rangle^*
#
# $$
#
# - **Normalization**: A state is **normalized** if $\langle\psi\vert \psi\rangle = 1$.
# - **Orthogonality**: Two states are **orthogonal** if $\langle\phi\vert \psi\rangle = 0$.
#
# :::
#
# **In vector form**, once we choose a basis:
#
# | Object | Notation | Type | Representation |
# |--------|----------|------|----------------|
# | **Ket** (state) | $\vert\psi\rangle$ | Column vector | $\begin{pmatrix} \psi_1 \\ \psi_2 \end{pmatrix}$ |
# | **Bra** (dual) | $\langle\psi\vert$ | Row vector | $(\psi_1^*\ \ \psi_2^*)$ |
# | **Inner product** | $\langle\phi\vert\psi\rangle$ | Scalar | $\phi_1^*\psi_1 + \phi_2^*\psi_2$ |
# | **Outer product** | $\vert\psi\rangle\langle\phi\vert$ | Matrix | $\begin{pmatrix} \psi_1\phi_1^* & \psi_1\phi_2^* \\ \psi_2\phi_1^* & \psi_2\phi_2^* \end{pmatrix}$ |
#
# :::{admonition} Orthonormal Basis
# :class: important
#
# A set of states $\{\vert e_1\rangle, \vert e_2\rangle, \ldots, \vert e_n\rangle\}$ forms an **orthonormal basis** if
#
# $$
#
# \langle e_i \vert e_j \rangle = \delta_{ij}
#
# $$
#
# and the basis is **complete** (any state can be expanded as $\vert \psi\rangle = \sum_i c_i \vert e_i\rangle$ with $c_i = \langle e_i \vert \psi\rangle$).
#
# :::
# :::{admonition} Derivation: Resolution of the Identity from an Orthonormal Basis
# :class: dropdown information
#
# **Claim.** If $\{\vert e_1\rangle, \ldots, \vert e_n\rangle\}$ is an orthonormal basis for an $n$-dimensional Hilbert space, then
#
# $$
#
# \sum_{i=1}^{n} \vert e_i\rangle\langle e_i\vert = \hat{I}
#
# $$
#
# This is called the **resolution of the identity** (or **completeness relation**).
#
# **Proof.** Let $\hat{P} = \sum_i \vert e_i\rangle\langle e_i\vert$. We show $\hat{P}\vert\psi\rangle = \vert\psi\rangle$ for every state $\vert\psi\rangle$.
#
# **Step 1: Expand $\vert\psi\rangle$ in the basis.** Since $\{\vert e_i\rangle\}$ is a basis, there exist coefficients $c_i$ such that $\vert\psi\rangle = \sum_j c_j \vert e_j\rangle$.
#
# **Step 2: Find the coefficients.** Taking the inner product with $\vert e_i\rangle$:
#
# $$
# \langle e_i\vert\psi\rangle = \sum_j c_j \langle e_i\vert e_j\rangle = \sum_j c_j \delta_{ij} = c_i
# $$
#
# So $c_i = \langle e_i\vert\psi\rangle$, confirming the coefficient formula.
#
# **Step 3: Apply $\hat{P}$.**
#
# $$
# \hat{P}\vert\psi\rangle = \sum_i \vert e_i\rangle\langle e_i\vert\psi\rangle = \sum_i \vert e_i\rangle c_i = \sum_i c_i\vert e_i\rangle = \vert\psi\rangle
# $$
#
# Since $\hat{P}\vert\psi\rangle = \vert\psi\rangle$ for every $\vert\psi\rangle$, we conclude $\hat{P} = \hat{I}$. $\square$
#
# **Key applications** of the resolution of the identity:
#
# **(a) Extracting components.** The expansion $\vert\psi\rangle = \sum_i \vert e_i\rangle\langle e_i\vert\psi\rangle$ is derived by inserting the identity: $\hat{I}\vert\psi\rangle = \left(\sum_i \vert e_i\rangle\langle e_i\vert\right)\vert\psi\rangle$.
#
# **(b) Inner products as sums.** Inserting $\hat{I}$ into $\langle\phi\vert\psi\rangle$:
#
# $$
# \langle\phi\vert\psi\rangle = \langle\phi\vert\hat{I}\vert\psi\rangle = \sum_i \langle\phi\vert e_i\rangle\langle e_i\vert\psi\rangle
# $$
#
# This expresses the inner product as a sum of products of components — identical to the formula $\sum_i \phi_i^* \psi_i$ in the $\{\vert e_i\rangle\}$ basis.
#
# **(c) Basis-independent trace.** For any operator $\hat{A}$, the trace $\mathrm{Tr}(\hat{A}) = \sum_i \langle e_i\vert\hat{A}\vert e_i\rangle$ is the same in every ONB. The resolution of the identity shows the overlap of two different ONB traces:
#
# $$
# \sum_i \langle e_i\vert\hat{A}\vert e_i\rangle = \sum_{ij} \langle e_i\vert f_j\rangle\langle f_j\vert\hat{A}\vert e_i\rangle = \sum_j \langle f_j\vert\hat{A}\left(\sum_i \vert e_i\rangle\langle e_i\vert\right)\vert f_j\rangle = \sum_j \langle f_j\vert\hat{A}\vert f_j\rangle
# $$
#
# **(d) Operator expansion.** Every operator $\hat{A}$ on an $n$-dimensional space can be expanded as a sum of $n^2$ outer products. Insert the identity on both sides:
#
# $$
# \hat{A} = \hat{I}\hat{A}\hat{I} = \sum_{ij} \vert e_i\rangle\langle e_i\vert\hat{A}\vert e_j\rangle\langle e_j\vert = \sum_{ij} A_{ij}\,\vert e_i\rangle\langle e_j\vert
# $$
#
# where $A_{ij} = \langle e_i\vert\hat{A}\vert e_j\rangle$ are the **matrix elements** of $\hat{A}$ in the basis.
# :::
#
# ### The Qubit State
#
# A qubit is defined by the existence of two **orthonormal computational basis states** $\vert 0\rangle$ and $\vert 1\rangle$:
#
# $$
#
# \langle 0\vert 0\rangle = 1, \quad \langle 1\vert 1\rangle = 1, \quad \langle 0\vert 1\rangle = 0
#
# $$ (eq-orthonormal-computational)
#
# **Any qubit state** can be written as a superposition of these basis states:
#
# $$
#
# \vert\psi\rangle = \alpha \vert 0\rangle + \beta \vert 1\rangle
#
# $$ (eq-general-qubit-state)
#
# where $\alpha, \beta \in \mathbb{C}$ are **amplitudes**.
#
# :::{admonition} Tip: Converting Between Ket and Vector Notation
# :class: hint
#
# To go from ket to vector: read off the coefficients of $\vert 0\rangle$ and $\vert 1\rangle$ and stack them as a column vector.
#
# $$
#
# \vert \psi\rangle = \alpha \vert 0\rangle + \beta \vert 1\rangle \quad \longleftrightarrow \quad \begin{pmatrix} \alpha \\ \beta \end{pmatrix}
#
# $$
#
# To go from vector to ket: interpret the top entry as the coefficient of $\vert 0\rangle$ and the bottom as $\vert 1\rangle$.
# :::
#
# ### Born's Rule and Normalization
#
# When we measure a qubit in the computational basis, the **Born rule** gives the measurement probabilities:
#
# :::{admonition} Born Rule
# :class: important
#
# If $\vert \psi\rangle = \alpha \vert 0\rangle + \beta \vert 1\rangle$, then measurement in the computational basis $\{\vert 0\rangle, \vert 1\rangle\}$ yields:
#
# $$
#
# P(\text{outcome } 0) = \vert\alpha\vert^2, \quad P(\text{outcome } 1) = \vert\beta\vert^2
#
# $$
#
# :::
#
# Probabilities must sum to one, so we require the **normalization condition**:
#
# $$
#
# \vert\alpha\vert^2 + \vert\beta\vert^2 = 1
#
# $$ (eq-normalization-condition)
#
# **Global phase is unobservable**: Two states $\vert \psi\rangle$ and $\mathrm{e}^{\mathrm{i}\gamma}\vert \psi\rangle$ (differing by a global phase $\gamma \in \mathbb{R}$) give identical probabilities for all measurements, since $\vert\mathrm{e}^{\mathrm{i}\gamma}\alpha\vert^2 = \vert\alpha\vert^2$. Measurement probabilities are the only source of knowledge about a quantum system, so global phase has no physical meaning and can be freely removed.
#
# ### Parameter Counting and the Bloch Sphere
#
# How many independent real parameters specify a qubit state?
#
# **Naive count:** Two complex amplitudes $\alpha, \beta$ give $2 \times 2 = 4$ real parameters (real and imaginary parts).
#
# **Constraints:**
# - Normalization ($\vert\alpha\vert^2 + \vert\beta\vert^2 = 1$) removes **1** parameter.
# - Global phase ($\vert\psi\rangle \cong \mathrm{e}^{\mathrm{i}\gamma}\vert\psi\rangle$) removes **1** parameter.
#
# **Effective count:** $4 - 1 - 1 = 2$ independent real parameters.
#
# We can write the most general qubit state using two angles $\theta$ and $\phi$:
#
# :::{admonition} Bloch Parametrization
# :class: important
#
# Every qubit state can be written (up to global phase) as
#
# $$
#
# \vert\psi\rangle = \cos(\theta/2) \vert 0\rangle + \mathrm{e}^{\mathrm{i}\phi} \sin(\theta/2) \vert 1\rangle
#
# $$ (eq-bloch-parametrization-standard)
#
# where $\theta \in [0, \pi]$ and $\phi \in [0, 2\pi)$. Normalization is automatic: $\cos^2(\theta/2) + \sin^2(\theta/2) = 1$.
#
# :::
#
# :::{admonition} Derivation: Bloch Sphere Parametrization
# :class: dropdown information
#
# **Goal:** Show that every normalized qubit state can be written (up to global phase) as $\vert\psi\rangle = \cos(\theta/2)\vert 0\rangle + \mathrm{e}^{\mathrm{i}\phi}\sin(\theta/2)\vert 1\rangle$.
#
# **Step 1: Write amplitudes in polar form.**
#
# Any complex number can be written as $\alpha = r_\alpha\,\mathrm{e}^{\mathrm{i}\phi_\alpha}$ with $r_\alpha \geq 0$, and similarly $\beta = r_\beta\,\mathrm{e}^{\mathrm{i}\phi_\beta}$.
#
# **Step 2: Apply normalization.**
#
# The condition $\vert\alpha\vert^2 + \vert\beta\vert^2 = 1$ becomes $r_\alpha^2 + r_\beta^2 = 1$. Since both are non-negative, parametrize:
#
# $$
# r_\alpha = \cos(\theta/2), \quad r_\beta = \sin(\theta/2), \quad \theta \in [0, \pi]
# $$
#
# (The half-angle $\theta/2$ is chosen so that $r_\alpha, r_\beta \geq 0$ without requiring $\theta > \pi$.)
#
# **Step 3: Fix the global phase.**
#
# The state is $\vert\psi\rangle = \cos(\theta/2)\,\mathrm{e}^{\mathrm{i}\phi_\alpha}\vert 0\rangle + \sin(\theta/2)\,\mathrm{e}^{\mathrm{i}\phi_\beta}\vert 1\rangle$. Multiply by $\mathrm{e}^{-\mathrm{i}\phi_\alpha}$ (a global phase — physically equivalent):
#
# $$
# \mathrm{e}^{-\mathrm{i}\phi_\alpha}\vert\psi\rangle = \cos(\theta/2)\vert 0\rangle + \mathrm{e}^{\mathrm{i}(\phi_\beta - \phi_\alpha)}\sin(\theta/2)\vert 1\rangle
# $$
#
# Setting $\phi = \phi_\beta - \phi_\alpha$ (the **relative phase**, which is observable), we arrive at the standard Bloch form. The angles $\theta \in [0,\pi]$ and $\phi \in [0,2\pi)$ are exactly the polar and azimuthal angles on a unit sphere.
# :::
#
# At this point, $\theta$ and $\phi$ appear to be just mathematical parameters. But notice: two real parameters pinpoint a point on a **sphere**. The angles $(\theta, \phi)$ are exactly the polar and azimuthal angles of a unit sphere in 3D. This gives a one-to-one correspondence between qubit states and points on the **Bloch sphere**.
#
# :::{margin}
# :::{figure} ../assets/figs/1-1-2-block_sphere.png
# :name: fig-bloch-sphere
# :width: 100%
#
# The Bloch sphere: pure qubit states map to points on the unit sphere. Polar angle $\theta$ (from north pole) and azimuthal angle $\phi$ (around z-axis) parametrize the state.
# :::
# :::
#
# ### The X, Y, Z Bases on the Bloch Sphere
#
# Three natural orthonormal bases correspond to antipodal pairs along the three Cartesian axes of the Bloch sphere:
#
# | Basis | Axis | Eigenstates | Bloch coordinates |
# |-------|------|-------------|-------------------|
# | **Z-basis** | $\hat{z}$ | $\vert 0\rangle = \begin{pmatrix} 1 \\ 0 \end{pmatrix}$, $\vert 1\rangle = \begin{pmatrix} 0 \\ 1 \end{pmatrix}$ | North/South pole: $(\theta, \phi) = (0, -)$ / $(\pi, -)$ |
# | **X-basis** | $\hat{x}$ | $\vert +\rangle = \frac{1}{\sqrt{2}}\begin{pmatrix} 1 \\ 1 \end{pmatrix}$, $\vert -\rangle = \frac{1}{\sqrt{2}}\begin{pmatrix} 1 \\ -1 \end{pmatrix}$ | $(\pi/2, 0)$ / $(\pi/2, \pi)$ |
# | **Y-basis** | $\hat{y}$ | $\vert \mathrm{i}\rangle = \frac{1}{\sqrt{2}}\begin{pmatrix} 1 \\ \mathrm{i} \end{pmatrix}$, $\vert \bar{\mathrm{i}}\rangle = \frac{1}{\sqrt{2}}\begin{pmatrix} 1 \\ -\mathrm{i} \end{pmatrix}$ | $(\pi/2, \pi/2)$ / $(\pi/2, 3\pi/2)$ |
#
# Each basis is associated with a **Pauli operator** ($\hat{X}$, $\hat{Y}$, $\hat{Z}$) whose eigenstates are that basis pair. The Pauli operators are introduced formally in [§1.1.3](1-1-3-hermitian-operators).
#
# :::{admonition} Basis Change and Inverse Relations
# :class: dropdown note
#
# To express a state in a different basis, invert the defining relations. For the X-basis:
#
# $$
#
# \vert 0\rangle = \frac{1}{\sqrt{2}}(\vert +\rangle + \vert -\rangle), \quad \vert 1\rangle = \frac{1}{\sqrt{2}}(\vert +\rangle - \vert -\rangle)
#
# $$ (eq-z-in-x-basis)
#
# For the Y-basis:
#
# $$
#
# \vert 0\rangle = \frac{1}{\sqrt{2}}(\vert \mathrm{i}\rangle + \vert \bar{\mathrm{i}}\rangle), \quad \vert 1\rangle = -\frac{\mathrm{i}}{\sqrt{2}}(\vert \mathrm{i}\rangle - \vert \bar{\mathrm{i}}\rangle)
#
# $$ (eq-z-in-y-basis)
#
# **Example:** To express $\vert \psi\rangle = \alpha \vert 0\rangle + \beta \vert 1\rangle$ in the X-basis, substitute:
#
# $$
#
# \vert \psi\rangle = \frac{\alpha + \beta}{\sqrt{2}}\vert +\rangle + \frac{\alpha - \beta}{\sqrt{2}}\vert -\rangle
#
# $$
#
# :::
#
# ### Spin Expectation Values and the Bloch Vector
#
# For a qubit state $\vert \psi\rangle$, the expectation values of the three Pauli operators form a 3D vector that points to the state's location on the Bloch sphere:
#
# :::{admonition} Bloch Vector
# :class: important
#
# For a state $\vert \psi\rangle = \cos(\theta/2)\vert 0\rangle + \mathrm{e}^{\mathrm{i}\phi}\sin(\theta/2)\vert 1\rangle$, the **Bloch vector** is
#
# $$
#
# \boldsymbol{n} = (\langle\hat{X}\rangle, \langle\hat{Y}\rangle, \langle\hat{Z}\rangle) = (\sin\theta\cos\phi,\; \sin\theta\sin\phi,\; \cos\theta)
#
# $$ (eq-bloch-vector)
#
# This is a **unit vector**: $\vert\boldsymbol{n}\vert = 1$. It points from the origin to the state's position on the Bloch sphere.
#
# :::
#
# :::{admonition} Derivation: Bloch Vector Components
# :class: dropdown information
#
# **Goal.** Show that for $\vert\psi\rangle = \cos(\theta/2)\vert 0\rangle + \mathrm{e}^{\mathrm{i}\phi}\sin(\theta/2)\vert 1\rangle$, the expectation values of the three Pauli operators are $\langle\hat{Z}\rangle = \cos\theta$, $\langle\hat{X}\rangle = \sin\theta\cos\phi$, $\langle\hat{Y}\rangle = \sin\theta\sin\phi$.
#
# **Setup.** Write the Pauli operators in the $\{\vert 0\rangle, \vert 1\rangle\}$ basis:
#
# $$
# \hat{X} = \begin{pmatrix} 0 & 1 \\ 1 & 0 \end{pmatrix}, \quad
# \hat{Y} = \begin{pmatrix} 0 & -\mathrm{i} \\ \mathrm{i} & 0 \end{pmatrix}, \quad
# \hat{Z} = \begin{pmatrix} 1 & 0 \\ 0 & -1 \end{pmatrix}
# $$
#
# The state in column-vector form is:
#
# $$
# \vert\psi\rangle = \begin{pmatrix} \cos(\theta/2) \\ \mathrm{e}^{\mathrm{i}\phi}\sin(\theta/2) \end{pmatrix}, \quad
# \langle\psi\vert = \begin{pmatrix} \cos(\theta/2) & \mathrm{e}^{-\mathrm{i}\phi}\sin(\theta/2) \end{pmatrix}
# $$
#
# **$\langle\hat{Z}\rangle$:**
#
# $$
# \langle\hat{Z}\rangle = \langle\psi\vert\hat{Z}\vert\psi\rangle = \cos^2(\theta/2)\cdot 1 + \sin^2(\theta/2)\cdot(-1) = \cos^2(\theta/2) - \sin^2(\theta/2) = \cos\theta
# $$
#
# using the double-angle identity $\cos\theta = \cos^2(\theta/2) - \sin^2(\theta/2)$.
#
# **$\langle\hat{X}\rangle$:**
#
# $$
# \hat{X}\vert\psi\rangle = \begin{pmatrix} 0 & 1 \\ 1 & 0 \end{pmatrix}\begin{pmatrix} \cos(\theta/2) \\ \mathrm{e}^{\mathrm{i}\phi}\sin(\theta/2) \end{pmatrix} = \begin{pmatrix} \mathrm{e}^{\mathrm{i}\phi}\sin(\theta/2) \\ \cos(\theta/2) \end{pmatrix}
# $$
#
# $$
# \langle\hat{X}\rangle = \cos(\theta/2)\cdot\mathrm{e}^{\mathrm{i}\phi}\sin(\theta/2) + \mathrm{e}^{-\mathrm{i}\phi}\sin(\theta/2)\cdot\cos(\theta/2)
# = \sin(\theta/2)\cos(\theta/2)\left(\mathrm{e}^{\mathrm{i}\phi} + \mathrm{e}^{-\mathrm{i}\phi}\right) = \frac{\sin\theta}{2}\cdot 2\cos\phi = \sin\theta\cos\phi
# $$
#
# using $\mathrm{e}^{\mathrm{i}\phi} + \mathrm{e}^{-\mathrm{i}\phi} = 2\cos\phi$ and $\sin\theta = 2\sin(\theta/2)\cos(\theta/2)$.
#
# **$\langle\hat{Y}\rangle$:**
#
# $$
# \hat{Y}\vert\psi\rangle = \begin{pmatrix} 0 & -\mathrm{i} \\ \mathrm{i} & 0 \end{pmatrix}\begin{pmatrix} \cos(\theta/2) \\ \mathrm{e}^{\mathrm{i}\phi}\sin(\theta/2) \end{pmatrix} = \begin{pmatrix} -\mathrm{i}\mathrm{e}^{\mathrm{i}\phi}\sin(\theta/2) \\ \mathrm{i}\cos(\theta/2) \end{pmatrix}
# $$
#
# $$
# \langle\hat{Y}\rangle = \cos(\theta/2)\cdot(-\mathrm{i}\mathrm{e}^{\mathrm{i}\phi})\sin(\theta/2) + \mathrm{e}^{-\mathrm{i}\phi}\sin(\theta/2)\cdot\mathrm{i}\cos(\theta/2)
# = \mathrm{i}\sin(\theta/2)\cos(\theta/2)\left(\mathrm{e}^{-\mathrm{i}\phi} - \mathrm{e}^{\mathrm{i}\phi}\right) = \frac{\sin\theta}{2}\cdot 2\sin\phi = \sin\theta\sin\phi
# $$
#
# using $\mathrm{e}^{-\mathrm{i}\phi} - \mathrm{e}^{\mathrm{i}\phi} = -2\mathrm{i}\sin\phi$, so $\mathrm{i}(-2\mathrm{i}\sin\phi) = 2\sin\phi$.
#
# **Conclusion.** The three expectation values are exactly the Cartesian components of the unit vector $\boldsymbol{n} = (\sin\theta\cos\phi, \sin\theta\sin\phi, \cos\theta)$, confirming that the Bloch vector points to the same location on the unit sphere as the state $\vert\psi\rangle$.
# :::
#
# This connects the abstract state description to a concrete geometric picture. Measuring spin along direction $\hat{\boldsymbol{n}}$ yields a definite outcome — the Bloch vector tells you where the spin "points." The open question: what exactly are these Pauli operators, and how do we formulate physical observables in general? This is the subject of [§1.1.3](1-1-3-hermitian-operators).
#
# :::{admonition} Discussion
# :class: dropdown tip
#
# **Why does the Bloch sphere fail for systems with more than two levels?**
#
# A qubit state is specified by 2 real parameters, mapping naturally to a 2-sphere. For a qutrit (3-level system), count: $2 \times 3 - 2 = 4$ real parameters. No simple sphere in 3D can parametrize a 4-dimensional space.
#
# - What geometric object parametrizes all pure qutrit states?
# - The Bloch sphere is useful because 3D rotations ($SU(2)$) correspond to single-qubit gates. Does a similar structure exist for qutrits?
#
# :::
#
#
# :::{admonition} Derivation: Transition Probability as a Bloch Sphere Inner Product
# :class: dropdown information
#
# **Claim.** For two qubit pure states with Bloch vectors $\hat{\boldsymbol{n}}_\psi$ and $\hat{\boldsymbol{n}}_\phi$,
#
# $$
# \vert\langle\phi\vert\psi\rangle\vert^2 = \frac{1 + \hat{\boldsymbol{n}}_\phi \cdot \hat{\boldsymbol{n}}_\psi}{2}
# $$
#
# **Proof.** Write both states in Bloch form:
#
# $$
# \vert\psi\rangle = \cos(\theta_1/2)\vert 0\rangle + \mathrm{e}^{\mathrm{i}\phi_1}\sin(\theta_1/2)\vert 1\rangle, \qquad
# \vert\phi\rangle = \cos(\theta_2/2)\vert 0\rangle + \mathrm{e}^{\mathrm{i}\phi_2}\sin(\theta_2/2)\vert 1\rangle
# $$
#
# **Step 1: Compute the overlap.**
#
# $$
# \langle\phi\vert\psi\rangle = \cos(\theta_2/2)\cos(\theta_1/2) + \mathrm{e}^{\mathrm{i}(\phi_1 - \phi_2)}\sin(\theta_2/2)\sin(\theta_1/2)
# $$
#
# **Step 2: Take the modulus squared.** Denoting $c_i = \cos(\theta_i/2)$, $s_i = \sin(\theta_i/2)$, $\Delta\phi = \phi_1 - \phi_2$:
#
# $$
# \vert\langle\phi\vert\psi\rangle\vert^2 = c_1^2 c_2^2 + s_1^2 s_2^2 + 2c_1 c_2 s_1 s_2 \cos(\Delta\phi)
# $$
#
# **Step 3: Expand using double-angle identities** ($c_i^2 = (1+\cos\theta_i)/2$, $s_i^2 = (1-\cos\theta_i)/2$, $2c_i s_i = \sin\theta_i$):
#
# $$
# c_1^2 c_2^2 + s_1^2 s_2^2 = \frac{(1+\cos\theta_1)(1+\cos\theta_2) + (1-\cos\theta_1)(1-\cos\theta_2)}{4}
# = \frac{2 + 2\cos\theta_1\cos\theta_2}{4} = \frac{1 + \cos\theta_1\cos\theta_2}{2}
# $$
#
# and $2c_1 c_2 s_1 s_2 = \tfrac{1}{2}\sin\theta_1\sin\theta_2$. Therefore:
#
# $$
# \vert\langle\phi\vert\psi\rangle\vert^2 = \frac{1 + \cos\theta_1\cos\theta_2 + \sin\theta_1\sin\theta_2\cos(\Delta\phi)}{2}
# $$
#
# **Step 4: Recognize the Bloch dot product.** The Bloch vectors are $\hat{\boldsymbol{n}}_i = (\sin\theta_i\cos\phi_i,\, \sin\theta_i\sin\phi_i,\, \cos\theta_i)$, so:
#
# $$
# \hat{\boldsymbol{n}}_1 \cdot \hat{\boldsymbol{n}}_2 = \sin\theta_1\sin\theta_2(\cos\phi_1\cos\phi_2 + \sin\phi_1\sin\phi_2) + \cos\theta_1\cos\theta_2
# = \sin\theta_1\sin\theta_2\cos(\phi_1-\phi_2) + \cos\theta_1\cos\theta_2
# $$
#
# This matches the numerator exactly, giving $\vert\langle\phi\vert\psi\rangle\vert^2 = (1 + \hat{\boldsymbol{n}}_\phi\cdot\hat{\boldsymbol{n}}_\psi)/2$. $\square$
#
# **Key consequences:**
# - Orthogonal states ($\langle\phi\vert\psi\rangle = 0$) satisfy $\hat{\boldsymbol{n}}_\phi\cdot\hat{\boldsymbol{n}}_\psi = -1$: they point to **antipodal** (opposite) points on the Bloch sphere. Two orthogonal qubit states are separated by $180°$, not $90°$.
# - Identical states ($\hat{\boldsymbol{n}}_\phi = \hat{\boldsymbol{n}}_\psi$): $\vert\langle\phi\vert\psi\rangle\vert^2 = 1$. ✓
# :::
#
# :::{admonition} Derivation: Every Single-Qubit Unitary Is a Bloch Sphere Rotation
# :class: dropdown information
#
# **Claim.** If $\hat{U} = \mathrm{e}^{-\mathrm{i}\theta(\hat{\boldsymbol{n}}\cdot\hat{\boldsymbol{\sigma}})/2}$ for a unit vector $\hat{\boldsymbol{n}}$ and angle $\theta$, then the state update $\vert\psi'\rangle = \hat{U}\vert\psi\rangle$ rotates the Bloch vector by angle $\theta$ about axis $\hat{\boldsymbol{n}}$:
#
# $$
# \boldsymbol{r}' = \cos\theta\,\boldsymbol{r} + (1-\cos\theta)(\hat{\boldsymbol{n}}\cdot\boldsymbol{r})\hat{\boldsymbol{n}} + \sin\theta\,\hat{\boldsymbol{n}}\times\boldsymbol{r} \qquad \text{(Rodrigues' formula)}
# $$
#
# **Step 1: Write $\hat{U}$ explicitly.** Let $A = \hat{\boldsymbol{n}}\cdot\hat{\boldsymbol{\sigma}}$. Since $A^2 = \hat{I}$ (any unit Pauli combination squares to the identity):
#
# $$
# \hat{U} = \cos(\theta/2)\hat{I} - \mathrm{i}\sin(\theta/2)\,A, \qquad \hat{U}^\dagger = \cos(\theta/2)\hat{I} + \mathrm{i}\sin(\theta/2)\,A
# $$
#
# **Step 2: Decompose $\hat{\sigma}_k$ into parallel and perpendicular parts.**
#
# $$
# \hat{\sigma}_k = n_k A + \hat{\sigma}_k^\perp, \qquad \hat{\sigma}_k^\perp \equiv \hat{\sigma}_k - n_k A
# $$
#
# - The **parallel part** $n_k A$ **commutes** with $A$: $[A,\, n_k A] = 0$.
# - The **perpendicular part** $\hat{\sigma}_k^\perp$ **anticommutes** with $A$: $\{A,\, \hat{\sigma}_k^\perp\} = 0$.
#
# *Proof of anticommutation.* Using $\hat{\sigma}_j\hat{\sigma}_k = \delta_{jk}\hat{I} + \mathrm{i}\epsilon_{jkl}\hat{\sigma}_l$:
#
# $$
# A\hat{\sigma}_k = n_k\hat{I} + \mathrm{i}(\hat{\boldsymbol{n}}\times\hat{\boldsymbol{\sigma}})_k, \qquad \hat{\sigma}_k A = n_k\hat{I} - \mathrm{i}(\hat{\boldsymbol{n}}\times\hat{\boldsymbol{\sigma}})_k
# $$
#
# so $A\hat{\sigma}_k + \hat{\sigma}_k A = 2n_k\hat{I}$. Therefore $A\hat{\sigma}_k^\perp + \hat{\sigma}_k^\perp A = 2n_k\hat{I} - 2n_k A^2 = 0$.
#
# **Step 3: Compute $\hat{U}\hat{\sigma}_k^\perp\hat{U}^\dagger$.**
#
# From $\{A, \hat{\sigma}_k^\perp\} = 0$ we get $A\hat{\sigma}_k^\perp = -\hat{\sigma}_k^\perp A$, hence $\mathrm{e}^{-\mathrm{i}\alpha A}\hat{\sigma}_k^\perp = \hat{\sigma}_k^\perp\mathrm{e}^{+\mathrm{i}\alpha A}$ for any scalar $\alpha$. Thus:
#
# $$
# \hat{U}\hat{\sigma}_k^\perp\hat{U}^\dagger = \hat{\sigma}_k^\perp\,\mathrm{e}^{\mathrm{i}\theta A/2}\,\hat{U}^\dagger = \hat{\sigma}_k^\perp\,\mathrm{e}^{\mathrm{i}\theta A/2}\,\mathrm{e}^{\mathrm{i}\theta A/2} = \hat{\sigma}_k^\perp\,\mathrm{e}^{\mathrm{i}\theta A} = \hat{\sigma}_k^\perp(\cos\theta + \mathrm{i}\sin\theta\, A)
# $$
#
# Now $\hat{\sigma}_k^\perp A = (\hat{\sigma}_k - n_k A)A = \hat{\sigma}_k A - n_k = -\mathrm{i}(\hat{\boldsymbol{n}}\times\hat{\boldsymbol{\sigma}})_k$, so:
#
# $$
# \hat{U}\hat{\sigma}_k^\perp\hat{U}^\dagger = \cos\theta\,\hat{\sigma}_k^\perp + \sin\theta\,(\hat{\boldsymbol{n}}\times\hat{\boldsymbol{\sigma}})_k
# $$
#
# **Step 4: Combine parallel and perpendicular.**
#
# The parallel part is unchanged: $\hat{U}(n_k A)\hat{U}^\dagger = n_k A$. Reassembling:
#
# $$
# \hat{U}\hat{\sigma}_k\hat{U}^\dagger = n_k A + \cos\theta\,\hat{\sigma}_k^\perp + \sin\theta\,(\hat{\boldsymbol{n}}\times\hat{\boldsymbol{\sigma}})_k
# = \cos\theta\,\hat{\sigma}_k + (1-\cos\theta)\,n_k A + \sin\theta\,(\hat{\boldsymbol{n}}\times\hat{\boldsymbol{\sigma}})_k
# $$
#
# **Step 5: Take the expectation value.** Using $r_k = \langle\hat{\sigma}_k\rangle = \langle\psi\vert\hat{\sigma}_k\vert\psi\rangle$ and $r_k' = \langle\hat{U}\hat{\sigma}_k\hat{U}^\dagger\rangle$:
#
# $$
# r_k' = \cos\theta\, r_k + (1-\cos\theta)\,n_k\,(\hat{\boldsymbol{n}}\cdot\boldsymbol{r}) + \sin\theta\,(\hat{\boldsymbol{n}}\times\boldsymbol{r})_k
# $$
#
# This is **Rodrigues' rotation formula**: the Bloch vector rotates rigidly by angle $\theta$ about $\hat{\boldsymbol{n}}$.
#
# **Consequence.** Every single-qubit gate is a rotation on the Bloch sphere. For example:
# - $\hat{X} = \mathrm{e}^{-\mathrm{i}(\pi/2)\hat{\sigma}^x}$: rotation by $\pi$ about the $x$-axis (swaps North and South poles)
# - $\hat{R}_z(\theta) = \mathrm{e}^{-\mathrm{i}\theta\hat{Z}/2}$: rotation about $z$ by $\theta$ (changes azimuthal angle $\phi \to \phi+\theta$)
# - Time evolution $\hat{U}(t) = \mathrm{e}^{-\mathrm{i}\hat{H}t/\hbar}$ with $\hat{H} = \frac{\hbar\omega}{2}\hat{Z}$: Larmor precession at angular velocity $\omega$ about $z$
# :::
#
# ### Summary
#
# - A **quantum state** $\vert \psi\rangle$ is an abstract vector in Hilbert space; its **representation** as components $(\alpha, \beta)$ depends on the chosen orthonormal basis.
# - The **Born rule** gives measurement probabilities: $P(0) = \vert\alpha\vert^2$, $P(1) = \vert\beta\vert^2$. **Global phase** is unobservable.
# - Parameter counting ($4 - 1 - 1 = 2$) shows a qubit state is specified by **two real angles** $(\theta, \phi)$, which naturally parametrize the **Bloch sphere**.
# - Three orthonormal bases (Z, X, Y) sit at antipodal pairs on the Bloch sphere, each associated with a Pauli operator.
# - The **Bloch vector** $\boldsymbol{n} = (\sin\theta\cos\phi, \sin\theta\sin\phi, \cos\theta)$ gives the geometric direction of the spin expectation values.

# %% [markdown]
# ## Homework
#
# **1.** A qubit is in the state $\vert \psi\rangle = \frac{1}{\sqrt{3}}\vert 0\rangle + \sqrt{\frac{2}{3}}\,\mathrm{e}^{\mathrm{i}\pi/4}\vert 1\rangle$. Find the Bloch sphere angles $(\theta, \phi)$ for this state by writing it in the standard parametrization $\vert \psi\rangle = \cos(\theta/2)\vert 0\rangle + \mathrm{e}^{\mathrm{i}\phi}\sin(\theta/2)\vert 1\rangle$.
#
# **2.** Show that two states $\vert \psi\rangle$ and $\mathrm{e}^{\mathrm{i}\alpha}\vert \psi\rangle$ (where $\alpha \in \mathbb{R}$) give the same measurement probabilities for any observable. That is, show $|\langle m \vert \psi \rangle\vert ^2 = |\langle m \vert \mathrm{e}^{\mathrm{i}\alpha}\psi \rangle\vert ^2$ for any state $\vert m\rangle$. Why does this mean global phase is unobservable?
#
# **3.** Express the state $\vert \psi\rangle = \frac{1}{\sqrt{2}}(\vert 0\rangle + \vert 1\rangle)$ in the X-basis $\{\vert +\rangle, \vert -\rangle\}$. Then express $\vert \phi\rangle = \frac{1}{\sqrt{2}}(\vert 0\rangle + \mathrm{i}\vert 1\rangle)$ in the X-basis. Compute the inner product $\langle\phi\vert \psi\rangle$ in both the Z-basis and the X-basis representations and verify you get the same result.
#
# **4.** Compute the Bloch vector $\boldsymbol{n} = (\langle \hat{X}\rangle, \langle\hat{Y}\rangle, \langle\hat{Z}\rangle)$ for the state $\vert \psi\rangle = \cos(\pi/8)\vert 0\rangle + \mathrm{e}^{\mathrm{i}\pi/3}\sin(\pi/8)\vert 1\rangle$. Verify that $\vert \boldsymbol{n}| = 1$.
#
# **5.** On the Bloch sphere, orthogonal quantum states correspond to antipodal points (diametrically opposite). Verify this explicitly: show that if $\vert \psi\rangle$ has Bloch angles $(\theta, \phi)$, then the orthogonal state $\vert \psi^\perp\rangle$ (satisfying $\langle\psi^\perp\vert \psi\rangle = 0$) has Bloch angles $(\pi - \theta, \phi + \pi)$.
#
# **6.** A qubit state $\vert \psi\rangle$ has Bloch vector $\boldsymbol{n} = (\sin\theta\cos\phi, \sin\theta\sin\phi, \cos\theta)$. Show that measuring in the computational basis gives $P(0) = \frac{1 + n_z}{2}$ and $P(1) = \frac{1 - n_z}{2}$, where $n_z = \cos\theta$. Interpret this geometrically: how does the measurement probability relate to the "height" of the Bloch vector?
#
# **7.** The inverse relations are given in Eq. [](#eq-z-in-y-basis). Use them to express $\vert +\rangle = \frac{1}{\sqrt{2}}(\vert 0\rangle + \vert 1\rangle)$ as a linear combination of $\vert \mathrm{i}\rangle$ and $\vert \bar{\mathrm{i}}\rangle$. Verify normalization and $\langle + \vert + \rangle = 1$ using your Y-basis coefficients.
#
# **8.** How many real parameters are needed to specify a general $n$-level quantum state (a "qudit")? Start with the naive count of $2n$ real numbers (from $n$ complex amplitudes), then subtract constraints from normalization and global phase. Verify your formula gives 2 for $n = 2$ (the qubit).
