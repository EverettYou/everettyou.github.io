# %% [markdown]
# # 3.3.2 WKB Approximation

# %% [markdown]
# :::{admonition} Prompts
# :class: tip
#
# - What is the WKB ansatz $\psi = A\,\mathrm{e}^{\mathrm{i}S/\hbar}$, and how does it reduce the Schr\"{o}dinger equation to the Hamilton-Jacobi equation?
# - How does WKB describe tunneling through a classically forbidden barrier?
# - What are turning points, and why do connection formulas require a $\pi/4$ phase shift?
# - When does the WKB approximation break down, and what is the precise validity criterion?
# :::

# %% [markdown]
# ## Lecture Notes
#
# ### Overview
#
# The **WKB (Wentzel-Kramers-Brillouin) approximation** solves the Schrödinger equation semiclassically when the potential varies slowly compared to the de Broglie wavelength. The ansatz $\psi = A\,\mathrm{e}^{\mathrm{i}S/\hbar}$ splits the wavefunction into a rapidly oscillating phase and a slowly varying amplitude. At leading order in $\hbar$, the phase satisfies the **Hamilton-Jacobi equation** — classical mechanics — while the amplitude is fixed by probability conservation.
#
# ### The WKB Ansatz
#
# Write the wavefunction as
#
# $$
# \psi(x, t) = A(x, t) \, \mathrm{e}^{\mathrm{i}S(x, t)/\hbar}
# $$
#
# Substituting into the Schrödinger equation and expanding in powers of $\hbar$:
#
# :::{admonition} WKB Hierarchy
# :class: important
#
# - **Leading order** ($\hbar^0$): the phase $S$ satisfies the **Hamilton-Jacobi equation**
#
# $$
# \frac{\partial S}{\partial t} + \frac{1}{2m}\left(\frac{\partial S}{\partial x}\right)^2 + V(x) = 0
# $$
#
# - **Next order** ($\hbar^1$): the amplitude $A$ satisfies a **continuity equation** — probability conservation.
# :::
#
# :::{admonition} Derivation: WKB Equations from Schrödinger
# :class: dropdown information
#
# Substitute $\psi = A\,\mathrm{e}^{\mathrm{i}S/\hbar}$ into $\mathrm{i}\hbar\partial_t\psi = -\frac{\hbar^2}{2m}\partial_x^2\psi + V\psi$. Computing derivatives:
#
# $$
# \frac{\partial^2\psi}{\partial x^2} = \left(A'' + \frac{2\mathrm{i}}{\hbar}A'S' + \frac{\mathrm{i}}{\hbar}AS'' - \frac{A}{\hbar^2}(S')^2\right) \mathrm{e}^{\mathrm{i}S/\hbar}
# $$
#
# Collecting by powers of $\hbar$ after canceling $\mathrm{e}^{\mathrm{i}S/\hbar}$:
#
# **Order $\hbar^0$ (imaginary part):** Hamilton-Jacobi equation for $S$.
#
# **Order $\hbar^1$ (real part):** $\partial_t A + \frac{1}{m}A'S' + \frac{A}{2m}S'' = 0$, a continuity equation for $A^2$ (probability density).
# :::
#
# ### Stationary States: Allowed and Forbidden Regions
#
# For energy eigenstates with $S(x,t) = S_0(x) - Et$, the Hamilton-Jacobi equation gives $\partial_x S_0(x) = \pm p(x)$ where $p(x) = \sqrt{2m(E - V(x))}$ is the local classical momentum.
#
# :::{admonition} WKB Wavefunctions
# :class: important
#
# - **Classically allowed** ($E > V$, real momentum):
#
#     $$
#     \psi(x) \sim \frac{1}{\sqrt{p(x)}} \exp\left(\pm\frac{\mathrm{i}}{\hbar}\int^x p(x')\,\mathrm{d}x'\right)
#     $$
#
#     where $p(x) = \sqrt{2m(E - V(x))}$.
#
# - **Classically forbidden** ($E < V$, imaginary momentum $p \to \mathrm{i}\kappa$):
#
#     $$
#     \psi(x) \sim \frac{1}{\sqrt{\kappa(x)}} \exp\left(\mp\frac{1}{\hbar}\int^x \kappa(x')\,\mathrm{d}x'\right)
#     $$
#
#     where $\kappa(x) = \sqrt{2m(V(x) - E)}$.
# :::
#
# The amplitude $1/\sqrt{p}$ reflects **probability conservation**: where the particle moves slowly (small $p$), it spends more time, so the probability density is larger.
#
# ### Connection Formulas at Turning Points
#
# At a **turning point** $x_0$ where $E = V(x_0)$, the momentum vanishes and the WKB solutions diverge. The exact solution near $x_0$ (an Airy function) bridges the two regions:
#
# **Allowed side** ($x < x_0$):
#
# $$
# \psi \sim \frac{C}{\sqrt{p}} \sin\left(\frac{1}{\hbar}\int_x^{x_0} p\,\mathrm{d}x' + \frac{\pi}{4}\right)
# $$
#
# **Forbidden side** ($x > x_0$):
#
# $$
# \psi \sim \frac{C}{\sqrt{\kappa}} \exp\left(-\frac{1}{\hbar}\int_{x_0}^x \kappa\,\mathrm{d}x'\right)
# $$
#
# The $\pi/4$ phase shift is essential — it accounts for the smooth transition through the turning point and determines the Maslov index in quantization conditions (§3.3.3).
#
# :::{admonition} Discussion: WKB Exactness
# :class: dropdown tip
#
# WKB is an approximation, yet it gives exact energy levels for the harmonic oscillator. This raises questions:
#
# - For which potentials is WKB exact? What special property must they have?
# - WKB predicts tunneling rates via $T \propto \mathrm{e}^{-2\gamma}$. Can you design a potential where WKB gives a very wrong tunneling rate?
# - Why does WKB work well for atomic energy levels when $\hbar$ is not truly small? Is there a hidden small parameter?
# :::
#
# ### Tunneling
#
# For a particle incident on a barrier where $V > E$ between turning points $a$ and $b$:
#
# :::{figure} ../assets/figs/3-3-2-tunneling.png
# :width: 75%
# :align: center
# :alt: Smooth potential barrier V(x) in black and real part of the wavefunction Re psi(x) in red; oscillations on the left with beating from reflection, exponential damping through the barrier, smaller transmitted oscillations on the right
#
# Potential $V(x)$ and $\mathrm{Re}\,\psi(x)$ for tunneling at energy $E$ below the barrier top: oscillatory regions outside the barrier and decay inside (compare the square barrier in homework **5**).
# :::
#
# :::{admonition} WKB Tunneling Probability
# :class: important
#
# $$
# T \approx \mathrm{e}^{-2\gamma}, \quad \gamma = \frac{1}{\hbar}\int_a^b \kappa(x)\,\mathrm{d}x = \frac{1}{\hbar}\int_a^b \sqrt{2m(V(x) - E)}\,\mathrm{d}x
# $$
#
# :::
#
# The tunneling probability is exponentially sensitive to the barrier width and height. The penetration depth into the forbidden region is $\lambda_\mathrm{decay} = \hbar/\kappa$.
#
# :::{admonition} Example: Electron Tunneling
# :class: dropdown example
#
# **Problem.** Estimate the tunneling probability for an electron through a 1 nm barrier with height 1 eV above its energy.
#
# **Solution.** $\gamma \approx (10^{-9}\;\mathrm{m})\sqrt{2(9.1\times 10^{-31}\;\mathrm{kg})(1.6\times 10^{-19}\;\mathrm{J})}/(10^{-34}\;\mathrm{J{\cdot}s}) \approx 5$, giving $T \sim \mathrm{e}^{-10} \approx 10^{-4.3}$. Rare but non-negligible at atomic scales — this is why quantum tunneling drives processes like alpha decay and scanning tunneling microscopy.
# :::
#
# ### Validity of WKB
#
# The WKB approximation requires the potential to vary slowly on the scale of the local de Broglie wavelength:
#
# $$
# \left|\frac{\mathrm{d}\ln p}{\mathrm{d}x}\right| = \left|\frac{V'(x)}{2(E - V(x))}\right| \ll 1
# $$
#
# This breaks down at turning points (remedied by connection formulas), potential discontinuities, and rapidly oscillating potentials.
#
# :::{admonition} See Also
# :class: seealso
#
# - [3.3.1 Stationary Phase Approximation](3-3-1-stationary-phase-approximation): Mathematical foundation of the semiclassical limit
# - [3.3.3 Bohr-Sommerfeld Quantization](3-3-3-bohr-sommerfeld-quantization): Quantization from WKB connection formulas
# - [3.4.3 Instantons](3-4-3-instantons): Tunneling via imaginary-time classical paths
# :::
#
#
# :::{admonition} Poll: WKB and tunneling
# :class: dropdown poll
#
# The WKB approximation gives $\psi(x) \propto p(x)^{-1/2} \exp(\pm \mathrm{i}\int p(x) \mathrm{d}x / \hbar)$ in classically allowed regions where $p^2 = 2m(E - V) > 0$. In a classically forbidden region where $V > E$, the momentum $p$ becomes imaginary. What does the WKB wavefunction predict in this region?
#
# (A) The wavefunction oscillates with increasing frequency as we penetrate deeper into the barrier.
#
# (B) The wavefunction decays exponentially, consistent with quantum tunneling through the barrier.
#
# (C) The wavefunction becomes complex and unphysical, indicating WKB breaks down.
#
# (D) The wavefunction remains constant, matching the classical expectation that particles never enter classically forbidden regions.
#
# :::
#
# ### Summary
#
# - **WKB ansatz** $\psi = A\,\mathrm{e}^{\mathrm{i}S/\hbar}$: phase obeys Hamilton-Jacobi (classical mechanics); amplitude fixed by probability conservation
# - **Connection formulas**: match oscillating and decaying solutions across turning points with $\pi/4$ phase shifts
# - **Tunneling**: $T \approx \mathrm{e}^{-2\gamma}$ with $\gamma = \hbar^{-1}\int \kappa\,\mathrm{d}x$ — exponentially suppressed by barrier width and height
# - **Validity**: excellent for smooth, slowly varying potentials; breaks down at turning points and sharp features

# %% [markdown]
# ## Homework
#
# **1. Hamilton-Jacobi equation.** Substitute the WKB ansatz $\psi(x) = A(x)\,\mathrm{e}^{\mathrm{i}S(x)/\hbar}$ into the time-independent Schr\"{o}dinger equation $-\frac{\hbar^2}{2m}\psi'' + V(x)\psi = E\psi$.
#
# (a) Collect terms by powers of $\hbar$ and show that at leading order ($\hbar^0$) the phase $S(x)$ satisfies $\frac{1}{2m}(S')^2 + V(x) = E$.
#
# (b) At next order ($\hbar^1$), show that the amplitude satisfies $2A'S' + AS'' = 0$. Integrate this to obtain $A \propto 1/\sqrt{S'} = 1/\sqrt{p(x)}$.
#
# **2. Allowed and forbidden regions.** A particle of energy $E$ moves in a slowly varying potential $V(x)$.
#
# (a) In a classically allowed region ($E > V$), write the WKB wavefunction $\psi \sim p^{-1/2}\exp(\pm\frac{\mathrm{i}}{\hbar}\int^x p\,\mathrm{d}x')$ and explain physically why the amplitude $1/\sqrt{p}$ means the particle is more likely to be found where it moves slowly.
#
# (b) In a classically forbidden region ($E < V$), write $p \to \mathrm{i}\kappa$ with $\kappa = \sqrt{2m(V-E)}$ and show that the wavefunction decays as $\psi \sim \kappa^{-1/2}\exp(-\frac{1}{\hbar}\int^x\kappa\,\mathrm{d}x')$.
#
# **3. Validity condition.** The WKB approximation requires $\vert\mathrm{d}\lambda/\mathrm{d}x\vert \ll 1$ where $\lambda(x) = 2\pi\hbar/p(x)$ is the local de Broglie wavelength.
#
# (a) Show that this is equivalent to $\vert V'(x)\vert \ll 2(E - V(x))^{3/2}\sqrt{2m}/\hbar$ in the allowed region.
#
# (b) For a linear potential $V(x) = Fx$ (constant force), identify where the WKB condition fails. Relate this to the turning point $x_0 = E/F$.
#
# (c) For a Gaussian barrier $V(x) = V_0\,\mathrm{e}^{-x^2/a^2}$ with energy $E = V_0/4$, estimate the classical turning points and discuss whether WKB is reliable throughout the allowed region.
#
# **4. Square barrier tunneling.** A particle of mass $m$ and energy $E < V_0$ encounters a rectangular barrier $V(x) = V_0$ for $0 < x < a$ and $V = 0$ elsewhere.
#
# (a) Using the WKB tunneling formula $T \approx \mathrm{e}^{-2\gamma}$ with $\gamma = \frac{1}{\hbar}\int_0^a\kappa\,\mathrm{d}x$, show that $T \approx \exp\!\left(-\frac{2a}{\hbar}\sqrt{2m(V_0 - E)}\right)$.
#
# (b) Evaluate $T$ for an electron ($m \approx 9.1\times 10^{-31}\,\text{kg}$) with $V_0 - E = 2\,\text{eV}$ and $a = 0.2\,\text{nm}$. Is tunneling significant at this scale?
#
# (c) By what factor does $T$ change if the barrier width doubles to $a = 0.4\,\text{nm}$? Explain why tunneling is exponentially sensitive to barrier width.
#
# **5. Penetration depth.** The characteristic decay length of the wavefunction in a forbidden region is $\lambda_\text{decay} = \hbar/\kappa$ where $\kappa = \sqrt{2m(V - E)}$.
#
# (a) Compute $\lambda_\text{decay}$ for an electron at a metal surface with work function $\phi = V - E = 5\,\text{eV}$. Express the answer in angstroms.
#
# (b) Explain why this length scale is relevant for scanning tunneling microscopy (STM): the tunneling current depends exponentially on the tip-surface distance.
#
# (c) Repeat the calculation for a proton ($m \approx 1.67\times 10^{-27}\,\text{kg}$) with the same barrier height. Why is proton tunneling much harder than electron tunneling?
#
# **6. Connection formula.** At a classical turning point $x_0$ where $E = V(x_0)$, the WKB solutions diverge because $p(x_0) = 0$.
#
# (a) Near $x_0$, linearize the potential as $V(x) \approx V(x_0) + V'(x_0)(x - x_0)$ and show that the Schr\"{o}dinger equation reduces to the Airy equation $\psi'' = z\psi$ (identify the variable $z$).
#
# (b) The Airy function smoothly connects the oscillating and decaying WKB forms. Explain why the connection formula includes a phase shift of $\pi/4$: on the allowed side, $\psi \sim p^{-1/2}\sin\!\left(\frac{1}{\hbar}\int_x^{x_0}p\,\mathrm{d}x' + \frac{\pi}{4}\right)$.
#
# (c) What goes wrong if one ignores the $\pi/4$ phase shift when applying quantization conditions?
#
# **7. Double-well tunneling.** Consider a symmetric double-well potential with two minima separated by a barrier of height $V_0$ and width $\sim a$.
#
# (a) Using the WKB tunneling formula, estimate the tunneling amplitude $\Delta \sim \hbar\omega\,\mathrm{e}^{-\gamma}$ where $\omega$ is the classical oscillation frequency in one well and $\gamma = \frac{1}{\hbar}\int_\text{barrier}\kappa\,\mathrm{d}x$.
#
# (b) Explain why the tunneling amplitude $\Delta$ lifts the degeneracy of the two ground states (one per well), producing a splitting $\Delta E \approx 2\Delta$.
#
# (c) For the ammonia molecule NH$_3$, the nitrogen atom tunnels through a barrier with $\gamma \approx 5$. Estimate the ratio $\Delta E/(\hbar\omega)$. Is the splitting large or small compared to the oscillation frequency?
