# %% [markdown]
# # 4.3.2 Landau Quantization

# %% [markdown]
# :::{admonition} Prompts
# :class: tip
#
# - How does Bohr-Sommerfeld quantization apply to cyclotron orbits? Why does it yield $E_n = (n + 1/2) \hbar \omega_c$?
#
# - In the Landau gauge with $\hat{\boldsymbol{A}} = (0, B\hat{x}, 0)$, why is $\hat{p}_y$ conserved? How does this reduce the problem to a harmonic oscillator?
#
# - What are guiding center coordinates $\hat{X}$ and $\hat{Y}$, and why is their commutator $[\hat{X}, \hat{Y}] = \mathrm{i}\ell_B^2$ profound for quantum mechanics?
#
# - What do wavefunctions in the lowest Landau level look like in complex coordinates? Why are they holomorphic polynomials times a Gaussian?
#
# - How does the degeneracy of each Landau level, $N_\phi = BA/\Phi_0$, scale with magnetic field strength?
# :::

# %% [markdown]
# ## Lecture Notes
#
# ### Overview
#
# Landau quantization describes the remarkable fate of a charged particle in a uniform magnetic field: continuous kinetic energy becomes quantized into discrete *Landau levels*, each with enormous degeneracy. The classical cyclotron orbit becomes a quantum harmonic oscillator. This is the foundation for understanding the quantum Hall effect and topological quantum phenomena.
#
# ### Semiclassical Quantization of Cyclotron Orbits
#
# Before solving the full quantum problem, we can gain insight from Bohr-Sommerfeld quantization (§3.3). A classical charged particle in a magnetic field $\boldsymbol{B} = B\hat{z}$ executes circular orbits at the cyclotron frequency:
#
# $$
# \omega_c = \frac{eB}{m}
# $$
#
# The action integral around a closed orbit is:
#
# $$
# \oint \boldsymbol{p} \cdot \mathrm{d}\boldsymbol{r} = 2\pi m \omega_c r^2 = 2\pi \hbar(n + \tfrac{1}{2})
# $$
#
# where $r$ is the orbit radius. This gives quantized energies:
#
# $$
# E_n = \frac{1}{2}m\omega_c^2 r^2 = (n + \tfrac{1}{2})\hbar\omega_c
# $$
#
# :::{admonition} Bohr-Sommerfeld Quantization of Cyclotron Motion
# :class: important
#
# $$
# E_n = \left(n + \tfrac{1}{2}\right)\hbar\omega_c \quad (n = 0, 1, 2, \ldots)
# $$
#
# This semiclassical result matches the exact quantum answer. The zero-point energy $E_0 = \frac{1}{2}\hbar\omega_c$ is purely quantum mechanical.
# :::
#
# ### Quantum Hamiltonian in the Landau Gauge
#
# The quantum Hamiltonian for a charged particle in a uniform magnetic field is:
#
# $$
# \hat{H} = \frac{1}{2m}(\hat{\boldsymbol{p}} - e\hat{\boldsymbol{A}})^2
# $$
#
# (In SI units; in Gaussian units use $q/c$ instead of $e$.)
#
# For $\boldsymbol{B} = B\hat{z}$, we choose the **Landau gauge**:
#
# $$
# \hat{\boldsymbol{A}} = (0, B\hat{x}, 0)
# $$
#
# This gauge breaks spatial translational symmetry in $x$ but reveals a crucial simplification: $\hat{p}_y$ commutes with the Hamiltonian and is a conserved quantum number.
#
# The kinetic momentum components become:
#
# $$
# \hat{\pi}_x = \hat{p}_x, \quad \hat{\pi}_y = \hat{p}_y - eB\hat{x}
# $$
#
# The Hamiltonian is:
#
# $$
# \hat{H} = \frac{\hat{p}_x^2}{2m} + \frac{(\hat{p}_y - eB\hat{x})^2}{2m}
# $$
#
# Using $[\hat{p}_x, \hat{x}] = -\mathrm{i}\hbar$, we can shift the origin: let $\hat{X} = \hat{x} + \hat{p}_y/(eB)$. Then:
#
# $$
# \hat{H} = \frac{\hat{p}_x^2}{2m} + \frac{1}{2}m\omega_c^2 \hat{X}^2
# $$
#
# This is a **harmonic oscillator in the $x$-direction** with frequency $\omega_c$. The variable $y$ (or equivalently $\hat{p}_y$) is a spectator: motion in $y$ is free.\n\n(Compare to §4.2 on gauge structure and Berry phase: the choice of gauge—Landau versus symmetric versus others—does not affect physical observables, though it reveals different quantum structures.)
#
# :::{admonition} Landau Gauge Reduction
# :class: note
#
# In the Landau gauge, the Hamiltonian becomes a shifted harmonic oscillator:
#
# $$
# \hat{H} = \frac{\hat{p}_x^2}{2m} + \frac{1}{2}m\omega_c^2\left(\hat{x} + \frac{\hat{p}_y}{eB}\right)^2
# $$
#
# The conserved momentum $\hat{p}_y$ labels degenerate states within each Landau level. The quantum number $n$ from the harmonic oscillator labels the Landau level.
# :::
#
# ### Landau Level Energies
#
# The energy eigenvalues are determined by the harmonic oscillator quantum number $n$:
#
# :::{admonition} Landau Level Energies and Degeneracy
# :class: important
#
# $$
# E_n = \left(n + \tfrac{1}{2}\right)\hbar\omega_c \quad (n = 0, 1, 2, \ldots)
# $$
#
# All states with the same $n$ but different $\hat{p}_y$ belong to the $n$-th **Landau level**. There is no energy splitting within a level (to leading order).
# :::
#
# ### Guiding Center Coordinates
#
# A key insight is that quantum mechanics forbids simultaneously specifying both the $x$ and $y$ positions of a particle in a strong magnetic field. We can define the **guiding center coordinates**:
#
# $$
# \hat{X} = \hat{x} + \frac{\hat{p}_y}{eB}, \quad \hat{Y} = \hat{y} - \frac{\hat{p}_x}{eB}
# $$
#
# These represent the classical center of the cyclotron orbit. Their commutator is:
#
# $$
# [\hat{X}, \hat{Y}] = -\mathrm{i}\frac{\hbar}{eB} = -\mathrm{i}\ell_B^2
# $$
#
# :::{admonition} Guiding Center Noncommutativity
# :class: important
#
# $$
# [\hat{X}, \hat{Y}] = -\mathrm{i}\ell_B^2 \quad \text{where} \quad \ell_B = \sqrt{\frac{\hbar}{eB}}
# $$
#
# This noncommutativity means that **guiding center positions cannot be simultaneously localized** to better than the magnetic length $\ell_B$. A quantum state occupies a minimum area of $\sim \ell_B^2$ in $(X, Y)$ space.
# :::
#
# ### Ladder Operators and Two Towers of States
#
# The Landau level structure involves *two independent sets* of ladder operators:
#
# 1. **Landau level ladder operators** $\hat{a}, \hat{a}^\dagger$: These raise and lower the Landau level index $n$.
#
# 2. **Guiding center ladder operators** $\hat{b}, \hat{b}^\dagger$: These label distinct states *within* a Landau level (different guiding centers).
#
# :::{admonition} Two Sets of Ladder Operators
# :class: note
#
# Define:
#
# $$
# \hat{a} = \sqrt{\frac{m\omega_c}{2\hbar}}\hat{X} + \mathrm{i}\sqrt{\frac{1}{2\hbar m\omega_c}}\hat{p}_x
# $$
#
# $$
# \hat{b} = \sqrt{\frac{m\omega_c}{2\hbar}}\hat{Y} + \mathrm{i}\sqrt{\frac{1}{2\hbar m\omega_c}}\hat{p}_y
# $$
#
# Both satisfy $[\hat{a}, \hat{a}^\dagger] = 1$ and $[\hat{b}, \hat{b}^\dagger] = 1$, but they commute with each other:
#
# $$
# [\hat{a}, \hat{b}] = [\hat{a}, \hat{b}^\dagger] = 0
# $$
#
# The Hamiltonian is:
#
# $$
# \hat{H} = \hbar\omega_c\left(\hat{a}^\dagger\hat{a} + \tfrac{1}{2}\right)
# $$
#
# States are labeled $\vert n, m \rangle$ where $\hat{a}^\dagger\hat{a}\vert n, m \rangle = n\vert n, m \rangle$ (Landau level) and $\hat{b}^\dagger\hat{b}\vert n, m \rangle = m\vert n, m \rangle$ (degeneracy index within the level).
# :::
#
# :::{admonition} Interpretation
# :class: note
#
# The appearance of two commuting sets of oscillators is profound:
# - Quantum mechanics generates an internal structure (the $\hat{b}$ oscillator) from the noncommutativity of guiding center positions.
# - States cannot be labeled by classical position $(X, Y)$; instead we need quantum numbers $n$ and $m$.
# - This structure underlies the topological properties of the quantum Hall effect.
# :::
#
# ### Complex Coordinates and Lowest Landau Level Wavefunctions
#
# In the lowest Landau level ($n = 0$), wavefunctions have a special structure in complex coordinates $z = x + \mathrm{i}y$.
#
# The lowest Landau level condition $\hat{a}\vert\psi\rangle = 0$ implies that the wavefunction must be **holomorphic** (analytic in $z$). The general form is:
#
# $$
# \psi_m(z, \bar{z}) = P_m(z) \exp\left(-\frac{\vert z\vert^2}{4\ell_B^2}\right)
# $$
#
# where $P_m(z)$ is a holomorphic polynomial of degree $m$ in $z$:
#
# $$
# P_m(z) = c_m z^m
# $$
#
# The Gaussian factor ensures normalizability; the polynomial factor labels the $m$ different degenerate states.
#
# :::{admonition} Lowest Landau Level Wavefunctions
# :class: important
#
# $$
# \psi_m(z, \bar{z}) = \frac{c_m}{\sqrt{\pi^{1/2}2^m m!\ell_B^{2m}}} z^m \exp\left(-\frac{\vert z\vert^2}{4\ell_B^2}\right)
# $$
#
# Each monomial $z^m$ corresponds to a distinct state within the $n=0$ level. The Gaussian width is set by $\ell_B$.
# :::
#
# :::{admonition} Why Holomorphic?
# :class: dropdown information
#
# The lowest Landau level condition is $\hat{a}\vert\psi\rangle = 0$, which expands to:
#
# $$
# \left[\sqrt{\frac{m\omega_c}{2\hbar}}z + \sqrt{\frac{1}{2\hbar m\omega_c}}\frac{\partial}{\partial z}\right]\psi = 0
# $$
#
# This is equivalent to $\frac{\partial\psi}{\partial\bar{z}} = 0$ (after rescaling), which means $\psi$ depends only on $z$, not $\bar{z}$. Thus $\psi$ is holomorphic.
# :::
#
# ### Degeneracy of Landau Levels
#
# The key fact is that many different guiding center positions (labeled by $m = 0, 1, 2, \ldots$) fit within the same Landau level. The number of distinct states in a Landau level is determined by the total magnetic flux through the sample.
#
# For a sample of area $A$ in a uniform field $B$:
#
# $$
# \Phi_{\text{total}} = BA
# $$
#
# Each state occupies an area $\sim \ell_B^2$ in guiding center space. The degeneracy is:
#
# $$
# N_\phi = \frac{\Phi_{\text{total}}}{\Phi_0} = \frac{BA}{\Phi_0}
# $$
#
# where $\Phi_0 = h/e = 4.14 \times 10^{-15}$ T·m$^2$ is the **flux quantum**.
#
# Equivalently:
#
# $$
# N_\phi = \frac{A}{\pi\ell_B^2}
# $$
#
# :::{admonition} Degeneracy Formula
# :class: important
#
# $$
# N_\phi = \frac{BA}{\Phi_0} = \frac{A}{\pi\ell_B^2}
# $$
#
# For a macroscopic sample ($A \sim 1 \text{ mm}^2$) at $B \sim 1$ T, the degeneracy is $N_\phi \sim 10^{10}$—a macroscopic number. All these states have (nearly) identical energy.
# :::
#
# This macroscopic degeneracy is the foundation for the quantum Hall effect (§4.3.3): when electrons fill a single Landau level, the system gains topological order and exhibits quantized Hall resistance. The ability to pack many independent states at nearly identical energy is essential for robust quantum behavior.
#
# :::{admonition} Discussion
# :class: dropdown tip
#
# In the quantum Hall regime, the degeneracy within a Landau level vastly exceeds the number of electrons:
#
# (a) Suppose you have a 2D electron system with area $A = 1 \text{ mm}^2$ at $B = 5$ T, containing $N_e = 10^{11}$ electrons. What is the filling factor $\nu = N_e/N_\phi$? How many Landau levels are partially occupied?
#
# (b) At very strong fields (say $B = 30$ T), why does the system become "incompressible"—unable to absorb additional electrons at a fixed Fermi energy?
#
# (c) If disorder lifts the degeneracy by $\Delta E \sim \hbar\omega_c/1000$, does this destroy the quantum Hall effect?
# :::
#
# ### Magnetic Length: The Fundamental Scale
#
# The magnetic length emerges naturally from the commutation relations:
#
# $$
# \ell_B = \sqrt{\frac{\hbar}{eB}}
# $$
#
# It is the only length scale in the problem and determines the wavefunction size, the separation between lattice sites in guiding center space, and the energy scale of orbital physics.
#
# :::{admonition} Magnetic Length (Recap)
# :class: note
#
# $$
# \ell_B = \sqrt{\frac{\hbar}{eB}} \approx 25.66 \text{ nm} \times (1 \text{ T}/B)^{1/2}
# $$
#
# For $B = 1$ T: $\ell_B \approx 25.66$ nm
# For $B = 10$ T: $\ell_B \approx 8.1$ nm
# :::
#
#
# :::{admonition} Poll: Landau level energy spacing
# :class: dropdown poll
#
# In a uniform magnetic field, the quantum mechanical energy levels are discrete and called *Landau levels*. The energy spacing between consecutive levels is $\Delta E = \hbar \omega_c = \hbar q B / m$, which is the quantum of cyclotron energy. Why does the energy spacing scale linearly with the magnetic field $B$?
#
# (A) The zero-point energy of the harmonic oscillator (analogy: a charged particle in a magnetic field behaves like a 2D harmonic oscillator) scales as $\hbar \omega_c \propto B$.
#
# (B) The density of states increases with $B$, so energy levels must be more widely spaced to maintain the same total number of states.
#
# (C) The magnetic length $\ell_B = \sqrt{\hbar / (qB)}$ decreases with $B$, confining the particle to a smaller region and increasing the kinetic energy.
#
# (D) Both (A) and (C).
#
# :::
#
# ### Summary
#
# - **Landau levels** $E_n = (n + 1/2)\hbar\omega_c$ arise from quantizing cyclotron orbits (Bohr-Sommerfeld or Landau gauge $\hat{\boldsymbol{A}} = (0, B\hat{x}, 0)$), with magnetic length $\ell_B = \sqrt{\hbar/(eB)}$ as the fundamental scale.
# - **Guiding center coordinates** $[\hat{X}, \hat{Y}] = -\mathrm{i}\ell_B^2$ encode noncommutative geometry; two ladder operator towers ($\hat{a}$ for level index, $\hat{b}$ for degeneracy) span each level.
# - **Lowest Landau level** wavefunctions are holomorphic polynomials $z^m$ times a Gaussian, the building blocks for quantum Hall physics.
# - **Macroscopic degeneracy** $N_\phi = BA/\Phi_0$ (one state per flux quantum) drives the integer and fractional quantum Hall effects.

# %% [markdown]
# ## Homework
#
# **1. Bohr-Sommerfeld quantization.** A charged particle in a uniform field $\boldsymbol{B} = B\hat{z}$ executes classical circular orbits.
#
# (a) Use $\oint \boldsymbol{p}\cdot\mathrm{d}\boldsymbol{r} = 2\pi m\omega_c r^2$ and the Bohr-Sommerfeld rule to derive $E_n = (n + \tfrac{1}{2})\hbar\omega_c$.
#
# (b) Compare this semiclassical result to the exact quantum answer. Does the zero-point energy $\frac{1}{2}\hbar\omega_c$ appear naturally?
#
# (c) The semiclassical approach does not reveal the massive degeneracy of each Landau level. What physical degree of freedom is it missing?
#
# **2. Gauge equivalence.** The Landau gauge $\boldsymbol{A}_L = (0, Bx, 0)$ and symmetric gauge $\boldsymbol{A}_S = \frac{B}{2}(-y, x, 0)$ both produce $\boldsymbol{B} = B\hat{z}$.
#
# (a) Find the gauge function $\alpha(x,y)$ such that $\boldsymbol{A}_S = \boldsymbol{A}_L + \nabla\alpha$.
#
# (b) The Landau gauge Hamiltonian has translational symmetry in $y$ ($[\hat{H}, \hat{p}_y] = 0$), while the symmetric gauge has rotational symmetry ($[\hat{H}, \hat{L}_z] = 0$). These are different symmetries! Explain how both can be correct descriptions of the same physics.
#
# (c) In the Landau gauge, eigenstates are labeled by $k_y$ (momentum quantum number). In the symmetric gauge, by $m$ (angular momentum). What is the gauge-invariant physical quantity that both quantum numbers parametrize?
#
# **3. Guiding center algebra.** Define guiding center coordinates $\hat{X} = \hat{x} + \hat{\pi}_y/(eB)$ and $\hat{Y} = \hat{y} - \hat{\pi}_x/(eB)$.
#
# (a) Compute $[\hat{X}, \hat{Y}]$ and express the result in terms of $\ell_B$.
#
# (b) The guiding center position is gauge-invariant (it depends on $\hat{\boldsymbol{\pi}}$, not $\hat{\boldsymbol{p}}$). Verify this by showing $\hat{X}$ and $\hat{Y}$ are unchanged under the Landau $\to$ symmetric gauge transformation.
#
# (c) The noncommutativity $[\hat{X}, \hat{Y}] = -\mathrm{i}\ell_B^2$ means the guiding center cannot be localized to a point — its position is "fuzzy" on the scale $\ell_B$. Use the uncertainty relation to find $\Delta X \cdot \Delta Y \geq \ell_B^2/2$. How does this constrain the area per state?
#
# **4. Two sets of ladders.** The Landau problem has two independent sets of ladder operators: $\hat{a}, \hat{a}^\dagger$ (cyclotron, sets the energy) and $\hat{b}, \hat{b}^\dagger$ (guiding center, parametrizes degeneracy).
#
# (a) The Hamiltonian is $\hat{H} = \hbar\omega_c(\hat{a}^\dagger\hat{a} + 1/2)$. Show that $[\hat{H}, \hat{b}] = [\hat{H}, \hat{b}^\dagger] = 0$, confirming that the guiding center operators do not affect the energy.
#
# (b) States in the $n$-th Landau level are $\vert n, m\rangle = \frac{(\hat{a}^\dagger)^n(\hat{b}^\dagger)^m}{\sqrt{n!m!}}\vert 0,0\rangle$. How many values of $m$ are allowed for a system of area $A$?
#
# (c) This structure is analogous to a 2D harmonic oscillator with both oscillators at the same frequency (but only one contributes to the energy). Explain why the "missing" energy from the $\hat{b}$ oscillator is exactly the classical kinetic energy of the guiding center drift.
#
# **5. Lowest Landau level.** In complex coordinates $z = x + \mathrm{i}y$, the LLL wavefunctions are $\psi_m(z) = C_m z^m \mathrm{e}^{-\vert z\vert^2/(4\ell_B^2)}$.
#
# (a) Show that the LLL condition $\hat{a}\vert\psi\rangle = 0$ requires $\psi$ to be holomorphic (analytic in $z$) times the Gaussian factor. Why can $\bar{z}$ not appear?
#
# (b) The $m = 0$ state is localized near the origin; the $m$-th state is localized near a ring of radius $r_m = \ell_B\sqrt{2m}$. Derive this radius from the probability density $\vert\psi_m\vert^2$.
#
# (c) For a circular sample of area $A$, the maximum $m$ is approximately $m_\text{max} = A/(2\pi\ell_B^2)$. Show that this gives the correct Landau level degeneracy $N_\phi = BA/\Phi_0$.
#
# **6. Flux counting.** The degeneracy of each Landau level is $N_\phi = \Phi_\text{total}/\Phi_0$ where $\Phi_0 = h/e$.
#
# (a) For a $1\,\text{mm} \times 1\,\text{mm}$ sample at $B = 10\,\text{T}$, compute $N_\phi$. Compare this number to the number of atoms in the sample.
#
# (b) Doubling $B$ doubles $N_\phi$ and halves $\ell_B^2$. Explain both effects physically: why does each Landau level accommodate more states, and why does each state occupy less area?
#
# (c) At filling factor $\nu = N_e/N_\phi = 1$, all LLL states are occupied. Adding one more electron requires promoting it to the second Landau level at energy cost $\hbar\omega_c$. This energy gap is the origin of the integer quantum Hall effect. Explain why $\nu$ changes as $B$ is varied at fixed electron density.
#
# **7. Symmetric gauge eigenstates.** In the symmetric gauge, the Hamiltonian commutes with $\hat{L}_z$ and the eigenstates have definite angular momentum $m$.
#
# (a) Write the symmetric gauge Hamiltonian in polar coordinates $(r, \theta)$ and separate the $\theta$ dependence using $\psi = R(r)\mathrm{e}^{\mathrm{i}m\theta}$. Show the radial equation is equivalent to a 1D harmonic oscillator in a shifted variable.
#
# (b) The lowest Landau level states with angular momentum $m \geq 0$ are $\psi_m \propto r^m \mathrm{e}^{\mathrm{i}m\theta}\mathrm{e}^{-r^2/(4\ell_B^2)}$. Verify these are eigenstates of both $\hat{H}$ (with $E = \frac{1}{2}\hbar\omega_c$) and $\hat{L}_z$ (with eigenvalue $m\hbar$).
#
# (c) In the Landau gauge, $\hat{p}_y$ is conserved but $\hat{L}_z$ is not. In the symmetric gauge, vice versa. Yet the physics is the same. Explain how the conserved quantity in each gauge is related to the guiding center position.
#
# **8. Landau level in graphene.** Graphene's low-energy electrons obey a Dirac-like equation with linear dispersion $E = \hbar v_F k$, leading to Landau levels $E_n = \text{sgn}(n)\,v_F\sqrt{2e\hbar\vert n\vert B}$ for $n = 0, \pm 1, \pm 2, \ldots$.
#
# (a) Show that the level spacing is not uniform: $E_1 - E_0 \neq E_2 - E_1$. For $B = 10\,\text{T}$ and $v_F = 10^6\,\text{m/s}$, compute $E_1$ in meV.
#
# (b) The $n = 0$ level sits at exactly zero energy and is shared equally between electrons and holes. Explain why this leads to a half-integer quantum Hall effect: $\sigma_{xy} = (n + 1/2)\times 4e^2/h$ (the factor 4 accounts for spin and valley degeneracy).
#
# (c) Compare the energy scale $E_1$ in graphene to $\hbar\omega_c$ in GaAs at the same field. Why is the QHE in graphene observable at room temperature while in GaAs it requires millikelvin temperatures?
