# %% [markdown]
# # 2.3.3 Non-Abelian Anyons

# %% [markdown]
# :::{admonition} Prompts
# :class: tip
#
# - In 2D, particles are not restricted to being fermions or bosons—anyons can exist with fractional statistics. What changes about the physics compared to 3D?
# - What distinguishes abelian from non-abelian anyons? How is this difference encoded in the braiding operations?
# - Explain fusion rules for non-abelian anyons. What does it mean for two anyons to "fuse," and why do the fusion outcomes matter?
# - What are $F$-symbols (also called 6j symbols)? How do they relate different ways of associating three or more anyons?
# - How could non-abelian anyons be harnessed for quantum computation? What makes topological protection superior to other error-correction schemes?
# - Fibonacci anyons are conjectured to exist in certain fractional quantum Hall states, yet we have not definitively observed them. If they were proven not to exist, how would that change your assessment of topological quantum computing as a viable path forward?
# :::

# %% [markdown]
# ## Lecture Notes
#
# Non-abelian anyons represent a deeper layer of topological order, where particle exchange operations do not commute and can perform quantum computations. Their potential for fault-tolerant quantum computing has made them targets of intense experimental effort, offering a path to quantum information protected by topology itself.
#
# ### What Makes Them Non-Abelian?
#
# **Non-abelian anyons** are anyonic quasiparticles whose **braiding operations** don't simply multiply the state by a phase factor. Instead, braiding can **mix different quantum states**.
#
# More precisely: when two non-abelian anyons exchange, the operation is represented by a **unitary matrix** acting on the Hilbert space of the system, not just a phase factor.
#
# :::{admonition} Abelian vs Non-Abelian Exchange
# :class: important
#
# **Abelian anyons** (phase anyons):
#
# $$
#
#
# R |\psi\rangle = \mathrm{e}^{\mathrm{i}\theta} |\psi\rangle
#
# $$
#
#
# Braiding produces only a global phase factor.
#
# **Non-abelian anyons**:
#
# $$
#
#
# R |\psi_1\rangle = U_{11} |\psi_1\rangle + U_{12} |\psi_2\rangle + \ldots
#
# $$
#
#
# where $U$ is a unitary matrix with multiple nonzero entries. Braiding mixes different quantum states.
# :::
#
# ### The Braid Group and Non-Commutativity
#
# The braiding operations form a **representation of the braid group** $B_N$. For $N$ anyons, the braid group is generated by elementary transpositions $R_i$ (exchange of anyons $i$ and $i+1$).
#
# For **abelian anyons**, this representation is **1-dimensional**: each $R_i$ acts as multiplication by a phase, and all $R_i$ commute: $[R_i, R_j] = 0$.
#
# For **non-abelian anyons**, the representation is **higher-dimensional**. The generators do NOT commute:
#
# $$
#
#
# R_i R_j \ne R_j R_i \quad (\text{for } |i-j|=1)
#
# $$
#
#
# :::{admonition} Yang-Baxter Equation
# :class: note
#
# The consistency of sequential exchanges is governed by the **Yang-Baxter equation**:
#
# $$
#
#
# R_{12} R_{13} R_{23} = R_{23} R_{13} R_{12}
#
# $$
#
#
# This ensures that different orderings of three-body exchanges give the same physical result (up to unitary equivalence). The Yang-Baxter equation is a fundamental consistency requirement for any anyon model.
# :::
#
# ### Quantum Information Storage and Computation
#
# :::{admonition} Degenerate Ground State Subspace
# :class: example
#
# A pair of non-abelian anyons has a **degenerate ground state** subspace. For instance, two anyons of type $a$ can fuse into different outcomes (fusion channels). The ground state manifold is spanned by these fusion possibilities.
#
# This degeneracy encodes quantum information: each pair of anyons can store approximately 1 qubit per fusion degree of freedom.
#
# Braiding operations act within this subspace, permuting the states without leaving the ground state manifold. Thus, braiding = quantum gate.
# :::
#
# :::{admonition} Topological Quantum Computation
# :class: important
#
# Quantum gates are implemented by **braiding non-abelian anyons**. The topological nature of braids ensures that:
#
# 1. The quantum gates are **protected** against local perturbations (small deformations of braid paths don't change the gate).
# 2. Errors due to noise are exponentially suppressed in the separation between anyons.
# 3. No active quantum error correction is needed; protection is intrinsic.
#
# This makes topological quantum computation inherently **fault-tolerant**.
# :::
#
# :::{admonition} Discussion: Universal Quantum Computation
# :class: dropdown warning
#
# **What is the minimum number of non-abelian anyons needed for universal quantum computation?** A pair of non-abelian anyons can store 1 qubit of information in their degenerate ground-state subspace. Braiding operations rotate within this subspace but are constrained by the fusion rules.
#
# The Fibonacci anyon (which appears in some topological states of the fractional quantum Hall effect) has a 3-dimensional fusion space, permitting a rich set of braid operations. Is there a fundamental lower bound on the number of anyons needed to achieve a universal gate set? If so, what physical principle determines this bound, and does it depend on the specific anyon model?
# :::
#
# ### Examples of Non-Abelian Anyons
#
# :::{admonition} Majorana Fermions
# :class: caution
#
# Proposals for creating non-abelian anyons include **Majorana zero modes** in topological superconductors and topological edge states.
#
# - Majorana fermions are their own antiparticles ($\gamma^\dagger = \gamma$).
# - Two Majorana zero modes can fuse into either vacuum or a regular fermion.
# - Braiding Majorana anyons implements non-abelian gates.
#
# However, **experimental confirmation of non-abelian braiding** remains challenging. Definitive signatures require demonstrating that braiding phases are non-abelian, not just abelian.
# :::
#
# :::{admonition} Fibonacci Anyons
# :class: example
#
# In certain fractional quantum Hall states (filling factor $\nu = 12/5$), the relevant quasiparticles are **Fibonacci anyons**.
#
# - Fusion rule: $a \times a = \mathbb{1} + a$ (the identity plus another $a$ anyon)
# - This 3-dimensional fusion space permits a universal set of braiding gates.
# - Fibonacci anyons are considered particularly promising for topological quantum computation.
# :::
#
# ### Summary and Physical Implications
#
# :::{admonition} Non-Abelian Braiding
# :class: important
#
# - **Non-abelian anyons** do not commute under braiding: exchange operations act as unitary matrices on a degenerate subspace, not simple phase factors.
#
# - **Braid group representation**: $N$ non-abelian anyons generate a $(d_a)^{N-2}$-dimensional Hilbert space, where $d_a$ is the quantum dimension. Braiding permutes basis states within this space.
#
# - **Yang-Baxter consistency**: Sequential exchanges must satisfy the Yang-Baxter equation: $R_{12} R_{13} R_{23} = R_{23} R_{13} R_{12}$.
#
# - **Topological quantum computation**: Gates are encoded as braid sequences. Topological protection makes gates robust against local perturbations.
#
# - **Examples**: Majorana fermions in topological superconductors, Fibonacci anyons in fractional quantum Hall states.
#
# - **Experimental status**: Direct observation of non-abelian braiding remains an open frontier.
# :::
#
# :::{admonition} Topological Protection: Why It Works
# :class: note
#
# Braiding operations are defined by the **topology** of the particle worldlines, not the detailed geometry. Two braid sequences that differ only by a continuous deformation (without crossings) are topologically equivalent and give the same unitary transformation. This makes the quantum gates inherently stable: small perturbations in particle positions do not corrupt the gate unless they cross additional particle worldlines.
# :::
# ## Fusion Rules
#
# ### Basic Concept
#
# In a system with anyons, two anyons can **fuse** (come close together and combine) into a single anyon of a different type. The **fusion rule** specifies which fusion channels are allowed:
#
# $$
#
#
# a \times b = \sum_c N_{ab}^c \, c
#
# $$ (eq-fusion-rule)
#
# where:
# - $a, b$ are anyon types (can be the same).
# - $c$ ranges over all possible fusion outcomes.
# - $N_{ab}^c \in \{0, 1, 2, \ldots\}$ is the **fusion multiplicity**: how many independent ways $a$ and $b$ can fuse into $c$.
#
# :::{admonition} Example: Fibonacci Anyons
# :class: example
#
#
# **Fibonacci anyons** are the simplest non-abelian anyons. There are two types: the **identity** $I$ (vacuum) and the **non-trivial** anyon $\tau$.
#
# Fusion rules:
#
# $$
#
#
# I \times I = I
#
# $$
#
#
# $$
#
# I \times \tau = \tau
#
# $$
#
#
# $$
#
# \tau \times \tau = I \oplus \tau
#
# $$ (eq-fibonacci-fusion)
#
# The last rule is the key: two $\tau$ anyons can fuse into either $I$ (vacuum) or $\tau$. There are **two channels**.
#
# :::
# ### Multiplicity and Degeneracy
#
# When $N_{ab}^c > 1$, there are **multiple independent ways** to fuse $a$ and $b$ into $c$. Each way corresponds to a different quantum state.
#
# For Fibonacci anyons at $\tau \times \tau = I \oplus \tau$:
# - One way fuses to $I$.
# - One way fuses to $\tau$.
#
# These are orthogonal outcomes.
# ## Modular Tensor Categories and TQFT
#
# ### The Mathematical Framework
#
# The complete description of anyonic systems is captured by **topological quantum field theory** (TQFT), or equivalently, **modular tensor categories** (MTCs).
#
# ### The Key Data: F-Symbols
#
# Beyond fusion rules, we need to specify **how to rearrange fusion trees**. This is encoded in the **F-symbols** (or **6-j symbols**):
#
# $$
#
#
# F^{d}_{abc}
#
# $$
#
#
# These are unitary matrices that relate different ways of fusing three anyons $a, b, c$ into $d$.
#
# $$
#
#
# \text{(fusion order 1:} (a \times b) \times c\text{)} \leftrightarrow \text{(fusion order 2:} a \times (b \times c)\text{)}
#
# $$
#
#
# ### The R-Matrices: Braiding
#
# The **R-matrices** (braiding matrices) specify how to exchange two anyons:
#
# $$
#
#
# R^c_{ab}
#
# $$
#
#
# These are unitary matrices acting on fusion channels. When two anyons $a$ and $b$ exchange, the state in different fusion channels gets mixed by $R^c_{ab}$.
#
# ### Consistency: Yang-Baxter Equation
#
# The F-symbols and R-matrices must satisfy consistency equations, most notably the **Yang-Baxter equation**:
#
# $$
#
#
# R_{12} R_{23} R_{12} = R_{23} R_{12} R_{23}
#
# $$
#
#
# This ensures that different ways of braiding multiple anyons give the same result.
# :::{admonition} Example: Fibonacci Anyons in Detail
# :class: example
#
#
# ### Fusion Rules (Recap)
#
# $$
#
#
# \tau \times \tau = I \oplus \tau
#
# $$
#
#
# Two $\tau$ anyons can fuse to $I$ or $\tau$—two orthogonal fusion channels.
#
# ### Quantum Dimension
#
# The **quantum dimension** of the $\tau$ anyon is determined by:
#
# $$
#
#
# d_\tau^2 = \sum_c N_{\tau\tau}^c d_c^2
#
# $$
#
#
# With $N_{\tau\tau}^I = N_{\tau\tau}^\tau = 1$ and $d_I = 1$:
#
# $$
#
#
# d_\tau^2 = 1 + d_\tau^2
#
# $$
#
#
# Wait—this is circular! The resolution: Fibonacci anyons satisfy
#
# $$
#
#
# d_\tau = \phi = \frac{1 + \sqrt{5}}{2} \approx 1.618 \quad \text{(golden ratio!)}
#
# $$
#
#
# Indeed: $\phi^2 = \phi + 1$, so $\phi^2 = 1 + \phi^2$ in the above (modulo subtlety with the $d_I$ term).
#
# ### R-Matrix
#
# The braiding of two $\tau$ anyons in their $\tau \times \tau \to \tau$ channel gives phase:
#
# $$
#
#
# R^\tau_{\tau\tau} = \mathrm{e}^{4\pi i/5}
#
# $$
#
#
# This is a rotation by $144°$.
#
# ### Why Fibonacci?
#
# The name "Fibonacci" comes from the fact that the quantum dimensions follow Fibonacci numbers in a generalized sense. The golden ratio naturally appears in their structure.
# :::
# ## Topological Quantum Computing
#
# ### Qubits from Anyons
#
# A **topological qubit** can be encoded in the fusion channel of two non-abelian anyons:
#
# $$
#
#
# |0\rangle_\text{topo} = |\text{anyon pair fuses to } I\rangle
#
# $$
#
#
# $$
#
# |1\rangle_\text{topo} = |\text{anyon pair fuses to } a \neq I\rangle
#
# $$
#
#
# The qubit is **topological**: encoded in a non-local property (fusion outcome) rather than a local quantum state.
#
# ### Quantum Gates via Braiding
#
# **Quantum gates** are implemented by braiding anyons:
#
# 1. Braiding two anyons around each other applies a unitary transformation (the R-matrix) to the qubit.
#
# 2. Different braiding paths give different gates. The gates are determined purely by **topology**, independent of precise trajectories.
#
# 3. **Example**: For Fibonacci anyons, certain braiding sequences implement universal quantum gates (enough to do any computation).
#
# ### Topological Protection
#
# **Error correction by topology**: Since the qubit is encoded in a topological property (fusion channel), local errors cannot change it.
#
# - A qubit in the "fuses to $I$" state remains in that state as long as the two anyons are well-separated.
# - To flip the qubit, an anyon would need to **pass through infinity** (a topologically nontrivial operation).
# - Errors from local noise are exponentially suppressed (decay as $\mathrm{e}^{-d/\xi}$ where $d$ is anyon separation and $\xi$ is a correlation length).
#
# **Advantage**: Quantum information is automatically protected without needing active error correction codes (though passive protection requires sufficient topological gap and separation).
# ## Universality and Computational Power
#
# ### Universal Gate Sets
#
# Not all anyon types are "universal" for quantum computation. **Universal anyons** allow us to implement an arbitrary quantum gate (up to approximation).
#
# **Fibonacci anyons are universal**: Certain sequences of braiding can approximate any unitary gate with arbitrary precision.
#
# **Abelian anyons are not universal**: Braiding of abelian anyons only produces abelian gates (diagonal in some basis), not full unitary operations.
#
# ### Computational Complexity
#
# With non-abelian anyons:
# - The Hilbert space dimension grows as $d^n$ where $d > 1$ is the quantum dimension.
# - For Fibonacci anyons: $d = \phi \approx 1.618$, so $n$ qubits have $\approx 1.618^n$ states.
# - This exponential scaling, combined with topological protection, offers computational advantage.
#
# ### Challenges
#
# - **Creating and isolating anyons**: Requires extreme conditions (low temperature, strong fields).
# - **Manipulating them**: Braiding must be done slowly (adiabatically) to avoid exciting unwanted states.
# - **Reading out results**: Measuring topological charge is non-trivial.
# - **Proof of concept**: No unambiguous experimental observation of anyons yet (though strong evidence in FQH systems).
# ## Physical Realizations of Non-Abelian Anyons
#
# ### Fractional Quantum Hall at $\nu = 5/2$
#
# The FQHE at filling factor $\nu = 5/2$ is believed to host **non-abelian Moore-Read state**:
# - Quasihole excitations are Fibonacci anyons (or similar).
# - Evidence from quasiparticle interference experiments and numerical simulations.
# - Still no definitive experimental confirmation, but strong indicators.
#
# ### Topological Insulators / Superconductors
#
# **Topological superconductors** with appropriate symmetries host non-abelian anyons:
# - Majorana fermions (a special non-abelian anyonic mode) emerge at vortex cores.
# - Platforms: p-wave superconductors, iron pnictides, proximity-induced on topological insulators.
# - Braiding of Majorana modes implements quantum gates.
#
# ### Quantum Spin Liquids
#
# Certain quantum spin liquids (exotic spin systems with no magnetic order) have anyonic excitations.
#
# ### Engineered Cold Atoms
#
# Using **synthetic gauge fields** in ultra-cold atomic systems, one can create analog environments where non-abelian anyons might exist.
#
# ### Topological Codes
#
# **Toric code** and related spin models defined on 2D lattices have non-abelian generalizations with anyonic excitations that can be simulated in quantum computers.
# ## Braiding Matrices and Computation
#
# ### Encoding Information in Fusion Channels
#
# Consider $n$ Fibonacci $\tau$ anyons. They can fuse in pairs:
# $(\tau_1 \times \tau_2) \to c_{12}$, then $(c_{12} \times \tau_3) \to c_{123}$, and so on.
#
# At each step, there are two fusion channels (to $I$ or $\tau$). With $n$ anyons, there are $F_{n-2}$ different fusion outcomes, where $F_n$ is the $n$-th Fibonacci number.
#
# ### Quantum Dimension of Multi-Particle Spaces
#
# - $n$ Fibonacci $\tau$ anyons: dimension $\sim F_{n-2} \times (d_\tau)^{n-1} = F_{n-2} \times \phi^{n-1}$.
# - This grows as $\phi^{n-1}$, much faster than the linear Hilbert space dimension per qubit.
#
# ### Gate Implementation
#
# A quantum gate is a sequence of braiding moves:
# 1. Label which pairs to braid and in what order.
# 2. The resulting unitary $U = R_{i_1} R_{i_2} \cdots R_{i_k}$ (composition of R-matrices) performs the gate.
# 3. Topological invariance: small deviations in trajectories don't change the gate (only the final topology matters).
# ## Comparison: Topological vs. Conventional Quantum Computing
#
# ### Conventional (Superconducting, Ion Traps)
#
# | Aspect | Conventional |
# |--------|-------------|
# | Protection | Active error correction codes needed |
# | Overhead | High (~1000 physical qubits per logical qubit) |
# | Error rates | ~$10^{-3}$ to $10^{-4}$ |
# | Temperature | mK (millikelvin) |
# | Stability | Qubits decohere in microseconds |
# | Implementation | Established, progressing rapidly |
#
# ### Topological (Anyons)
#
# | Aspect | Topological |
# |--------|------------|
# | Protection | Passive, topological (no codes needed in principle) |
# | Overhead | Low (if topological protection works) |
# | Error rates | Exponentially suppressed with anyon separation |
# | Temperature | Very low (strong gaps needed), or engineered systems |
# | Stability | Protected from local noise by design |
# | Implementation | Still experimental, fundamental challenges remain |
#
# **Tradeoff**: Topological quantum computers offer inherent fault-tolerance but are harder to realize experimentally. Conventional systems are closer to practical implementation but require elaborate error correction.
# ## Research Frontiers
#
# ### Observing Non-Abelian Statistics
#
# Direct experimental evidence for non-abelian anyons remains elusive:
# - Charge measurements (via shot noise) in FQHE are consistent with fractional charge.
# - Shot noise also provides evidence for fractional statistics (abelian).
# - Non-abelian braiding statistics are harder to measure directly.
#
# ### Majorana Zero Modes
#
# Recent experimental programs focus on Majorana fermions in topological superconductors:
# - Claims of observation in nanowires, but interpretation debated.
# - If confirmed, braiding experiments could test non-abelian statistics.
#
# ### Digital Simulation
#
# A near-term approach: **simulate** anyonic systems on quantum computers and test braiding rules computationally.
#
# ### Materials Discovery
#
# Search for natural or engineered materials with non-abelian anyonic excitations (topological superconductors, spin liquids, etc.).
# ## Summary
#
# - **Non-abelian anyons**: Braiding mixes different quantum states (R-matrices are non-diagonal).
# - **Fusion rules**: Specify allowed fusion outcomes and multiplicities; form algebraic structure.
# - **F-symbols**: Encode rearrangement of fusion trees; must satisfy Yang-Baxter equation.
# - **Fibonacci anyons**: Quantum dimension $\phi$ (golden ratio); universal for quantum computation.
# - **Topological qubits**: Encoded in fusion channels; protected from local decoherence by topology.
# - **Quantum gates**: Implemented via braiding; topologically protected and fault-tolerant by design.
# - **Physical systems**: FQHE at $\nu = 5/2$, topological superconductors, spin liquids (candidate platforms).
# - **Challenge**: Creating, isolating, and manipulating anyons experimentally remains open.
# - **Promise**: Fault-tolerant quantum computation without active error correction.
#
# :::{admonition} See Also
# :class: seealso
#
# - **[2 3 2 Abelian Anyons](2-3-2-abelian-anyons.ipynb)**: Abelian anyons and braiding in 2D
# - **[4 5 3 Topology](../ch4_phase-and-gauge/4-5-3-topology.ipynb)**: Topological order and protected degeneracies
# - **[6 4 3 Error Correction](../ch6_quantum-foundations/6-4-3-error-correction.ipynb)**: Topological quantum error correction
# :::

# %% [markdown]
# ## Homework
#
# **1. Non-abelian vs. Abelian Braiding (Conceptual)**
#
# Consider two anyons of type $a$ that braid around each other. In an abelian system, the braiding operation is represented by multiplication by a phase $\mathrm{e}^{\mathrm{i}\theta}$. For non-abelian anyons, the same operation is a unitary matrix $R^c_{aa}$ in some multi-dimensional space.
#
# (a) What does the dimensionality of the R-matrix tell us about the system? Why can an abelian anyon's braiding be represented by a single phase?
#
# (b) Suppose we have two non-abelian anyons with a 2D braiding space. Write down a general form for the R-matrix and explain what it means physically for the braiding operation to "mix" two quantum states.
#
# (c) Why is non-commutativity of braiding operations ($R_1 R_2 \neq R_2 R_1$) a necessary feature for topological quantum computation?
#
# **2. Fusion Channels and Quantum States (Conceptual)**
#
# Two Fibonacci $\tau$ anyons can fuse according to the rule $\tau \times \tau = I \oplus \tau$.
#
# (a) Explain what the symbol $\oplus$ means in this fusion rule. How many independent fusion outcomes are there, and what do they represent physically?
#
# (b) If we have three $\tau$ anyons labeled 1, 2, and 3, can they all fuse into the vacuum state $I$? Justify your answer using the fusion rule.
#
# (c) In a topological qubit encoded in the fusion channel of two $\tau$ anyons, why is the qubit information protected from local environmental noise?
#
# **3. Quantum Dimension and Fibonacci Numbers (Derivation)**
#
# The quantum dimension of a Fibonacci $\tau$ anyon must satisfy:
#
# $$d_\tau^2 = d_I^2 + d_\tau^2$$
#
# where $d_I = 1$ is the quantum dimension of the identity.
#
# (a) This equation appears contradictory. Explain how the resolution involves recognizing that $\tau$ can fuse to two different outcomes.
#
# (b) Show that $d_\tau = \phi = \frac{1+\sqrt{5}}{2}$ (the golden ratio) solves the correct equation relating quantum dimensions and fusion multiplicities.
#
# (c) Verify that $\phi^2 = \phi + 1$ and relate this property to why Fibonacci anyons are named after Fibonacci numbers.
#
# **4. Braiding as a Unitary Transformation (Short Derivation)**
#
# The R-matrix for Fibonacci $\tau$ anyons in the $\tau \times \tau \to \tau$ fusion channel is:
#
# $$R^\tau_{\tau\tau} = \mathrm{e}^{4\pi i/5}$$
#
#
# (a) What is the angle (in degrees) of this rotation? Express the result in the form $\mathrm{e}^{\mathrm{i}\theta}$.
#
# (b) Show that $(R^\tau_{\tau\tau})^5 = 1$ (i.e., braiding the same pair 5 times returns to the identity). What is the physical interpretation?
#
# (c) How does this result relate to the universal quantum computation capabilities of Fibonacci anyons?
#
# **5. Fusion Trees and F-Symbols (Physical Reasoning)**
#
# Consider four Fibonacci $\tau$ anyons. They can be fused in different orders:
# - Order 1: $(\tau_1 \times \tau_2) \times (\tau_3 \times \tau_4)$
# - Order 2: $((\tau_1 \times \tau_2) \times \tau_3) \times \tau_4$
#
# (a) Draw the two different fusion trees (as binary trees) corresponding to these orders.
#
# (b) The F-symbols relate these different orderings. Why must the result of a fusion be **independent** of the order in which we combine anyons? (Hint: think about what it means physically for the system to be well-defined.)
#
# (c) The Yang-Baxter equation $R_{12}R_{23}R_{12} = R_{23}R_{12}R_{23}$ is a consistency condition. In one sentence, explain why this equation must hold for any physically realizable system of non-abelian anyons.
#
# **6. Topological Qubits and Decoherence (Conceptual)**
#
# In conventional quantum computing, a qubit stored in a two-level atom decoheres over time due to environmental interactions. In topological quantum computing, qubits are encoded in the fusion outcome of two non-abelian anyons.
#
# (a) Why is a topological qubit more robust to decoherence than a qubit stored in a local degree of freedom?
#
# (b) Suppose two $\tau$ anyons are separated by distance $d$ and are in the fusion channel $|\tau \times \tau \to I\rangle$. What would need to happen for the qubit to flip to $|\tau \times \tau \to \tau\rangle$?
#
# (c) Explain briefly why the error rate for topological qubits is suppressed exponentially with the anyon separation, while conventional qubit error rates are roughly constant over time.
#
# **7. Physical Realization and Experimental Challenges (Research Investigation)**
#
# Non-abelian anyons could be realized in several platforms: fractional quantum Hall effect at $\nu = 5/2$, topological superconductors with Majorana fermions, or quantum spin liquids.
#
# (a) For each platform, briefly identify one key experimental challenge in creating and manipulating non-abelian anyons.
#
# (b) Why is **measuring** the result of topological quantum computation (i.e., extracting the final answer) more difficult than the computation itself?
#
# (c) Propose one alternative approach (besides direct real-world realization) for testing the properties and braiding rules of non-abelian anyons. What are its advantages and limitations compared to direct experiments?
