# %% [markdown]
# # 3.3.1 Stationary Phase Approximation

# %% [markdown]
# :::{admonition} Prompts
# :class: tip
#
# - What is the stationary phase approximation and under what mathematical condition does it apply?
# - How does the stationary point in the phase correspond physically to the classical path?
# - What happens to the "stationary region" (range of paths contributing) as $\hbar \to 0$?
# - How do quantum fluctuations around the classical path affect the propagator at finite $\hbar$?
# - Can multiple stationary points interfere with each other, and what does this tell you about multi-path scenarios?
# :::

# %% [markdown]
# ## Lecture Notes
#
# :::{admonition} Definition
# :class: important
#
# The **stationary phase approximation** (SPA) reveals the deep connection between classical and quantum mechanics. When $\hbar$ is small, oscillatory integrals are dominated by points where the phase is stationary. This principle underlies the emergence of classical trajectories from quantum path integrals and explains why the classical path is special.
# :::
#
# :::{admonition} Discussion: Stationary Phase and Classical Emergence
# :class: dropdown warning
#
# The stationary phase approximation says that as $\hbar \to 0$, the phase oscillates rapidly except near paths where $\frac{\delta S}{\delta \text{path}} = 0$ (classical paths). This provides a bridge between quantum and classical mechanics:
#
# - In the limit $\hbar \to 0$, does stationary phase become *exact* (zero error), or just increasingly accurate? What controls the error term?
# - For a potential with multiple classical paths (e.g., reflection and transmission), which paths contribute to the sum? Do they interfere constructively or destructively?
# - Consider a "chaotic" classical system where tiny differences in initial conditions lead to wildly different trajectories. How does the path integral handle this chaos in quantum mechanics? Does quantum mechanics "smooth out" chaos?
# - For a quantum tunneling event (path goes through classically forbidden region), there is no classical path. Yet the path integral includes such paths. How does SPA handle this non-classical contribution?
# :::
# ### The Stationary Phase Approximation (SPA)
#
# Many integrals in quantum mechanics have the form
#
# $$I = \int \mathrm{e}^{\mathrm{i}\Phi(x)/\hbar} f(x) \, \mathrm{d}x$$
#
#
# where $\Phi(x)$ is a **phase function**, $f(x)$ is a slowly-varying **amplitude**, and $\hbar$ is small. When $\hbar$ is tiny, the integrand oscillates wildly unless $\Phi$ is slowly varying.
#
# :::{admonition} Stationary Phase Approximation
# :class: important
#
# The integral is dominated by points where the phase is **stationary**:
#
# $$\frac{\mathrm{d}\Phi}{dx}\bigg|_{x_0} = 0$$
#
#
# Near a stationary point $x_0$, expand the phase:
#
# $$\Phi(x) \approx \Phi(x_0) + \frac{1}{2}\Phi''(x_0)(x - x_0)^2 + \cdots$$
#
#
# Then:
#
# $$I \approx \mathrm{e}^{\mathrm{i}\Phi(x_0)/\hbar} f(x_0) \int \mathrm{e}^{\mathrm{i}\Phi''(x_0)(x-x_0)^2/(2\hbar)} dx$$
#
#
# Using the Gaussian integral formula $\int \mathrm{e}^{\mathrm{i}ax^2} dx = \sqrt{\pi/(ia)}$:
#
# $$I \approx \mathrm{e}^{\mathrm{i}\Phi(x_0)/\hbar} f(x_0) \sqrt{\frac{2\pi\hbar}{i\Phi''(x_0)}}$$
#
#
# :::
#
# #### Conditions for Validity
#
# The SPA is valid when:
#
# 1. **Clear stationary point**: Unique or isolated points where $d\Phi/dx = 0$
# 2. **Large second derivative**: $|\Phi''(x_0)|$ is not too small, ensuring the quadratic expansion is accurate
# 3. **Slowly-varying amplitude**: $f(x)$ varies over a scale much longer than the stationary region
# 4. **Small $\hbar$**: Equivalently, $\Phi \gg \hbar$ (the classical action is large)
#
# #### Region of Significant Contribution
#
# The width of the stationary region is estimated by:
#
# $$\Phi''(x - x_0)^2 \sim \hbar \quad \Rightarrow \quad (x - x_0) \sim \sqrt{\hbar/\Phi''}$$
#
#
# **Small $\hbar$** means this region is **narrow**: quantum fluctuations are confined to a region of size $\sim \sqrt{\hbar}$, while the amplitude $f$ varies over distance $\sim 1$. Thus $f$ is nearly constant over the stationary region.
#
# ### Why the Classical Path Dominates
#
# In the path integral,
#
# $$K(\boldsymbol{x}_f, t_f; \boldsymbol{x}_i, t_i) = \int_{\text{all paths}} \mathrm{e}^{\mathrm{i}S[\boldsymbol{x}]/\hbar} \, \mathcal{D}[\boldsymbol{x}]$$
#
#
# the **phase** is $\Phi[\boldsymbol{x}] = S[\boldsymbol{x}]/\hbar$, where $S$ is the **classical action**.
#
# #### Classical Path Satisfies Stationarity
#
# The **classical path** $\boldsymbol{x}_{\text{cl}}(t)$ is defined by the principle of stationary action:
#
# $$\frac{\delta S}{\delta \boldsymbol{x}(t)}\bigg|_{\boldsymbol{x}_{\text{cl}}} = 0$$
#
#
# This is the **Euler-Lagrange equation**—Newton's equations of motion in Lagrangian form.
#
# By the stationary phase approximation, paths with $\delta S = 0$ (the classical path and a small neighborhood around it) **interfere constructively**—their phases are nearly identical, so amplitudes add coherently.
#
# #### Destructive Interference Away from the Classical Path
#
# Consider two neighboring paths that differ slightly. If neither is the classical path, their actions differ:
#
# $$\Delta S = S[\boldsymbol{x}_2] - S[\boldsymbol{x}_1] = \int \frac{\delta S}{\delta \boldsymbol{x}} \delta\boldsymbol{x} \, \mathrm{d}t + O((\delta\boldsymbol{x})^2)$$
#
#
# Since $\delta S/\delta\boldsymbol{x} \ne 0$ away from the classical path, infinitesimal variations $\delta\boldsymbol{x}$ produce changes in action $\Delta S$ that are **not second-order small**. Thus:
#
# - Paths clustered around $\boldsymbol{x}_{\text{cl}}$ have action differences $\sim \sqrt{\hbar}$ (or smaller), giving phase differences $\sim 1$—they **interfere coherently**
# - Paths at distance $\sim 1$ from $\boldsymbol{x}_{\text{cl}}$ have action differences $\sim 1$ (in units of $\hbar$), giving phase differences $\sim 1/\hbar \gg 1$—they **oscillate rapidly and cancel**
#
# :::{admonition} Note: Quantum-to-Classical Transition
# :class: note
#
# In the **classical limit** $\hbar \to 0$:
# - The coherent region shrinks to zero size
# - Only the single classical path remains
# - All other paths are suppressed by rapid oscillation
# - The particle follows a definite trajectory
#
# In the **quantum regime** (small, complex systems):
# - Many paths have action $\sim \hbar$ and contribute significantly
# - Quantum superposition of all paths gives interference patterns
# - The particle has no definite trajectory; it explores all possibilities with different probabilities
# :::
#
# ### The Second Variation and Quantum Fluctuations
#
# The path integral is dominated by configurations close to the classical path. Expanding the action to second order gives:
#
# $$S[\boldsymbol{x}_{\text{cl}} + \delta\boldsymbol{x}] \approx S[\boldsymbol{x}_{\text{cl}}] + \frac{1}{2}\int dt \, \frac{\delta^2 S}{\delta\boldsymbol{x}^2} (\delta\boldsymbol{x})^2$$
#
#
# The second-order term is a **Gaussian functional integral** that can be evaluated analytically, yielding the propagator in the **stationary phase approximation**:
#
# $$K(\boldsymbol{x}_f, t_f; \boldsymbol{x}_i, t_i) \approx \mathrm{e}^{\mathrm{i}S_{\text{cl}}/\hbar} \sqrt{\frac{1}{\det(\delta^2 S/\delta\boldsymbol{x}^2)}}$$
#
#
# This includes both the classical action and a **quantum correction factor** from fluctuations.
#
# :::{admonition} Derivation: Second Variation and Quantum Corrections
# :class: dropdown note
#
# To understand quantum corrections beyond the classical path, expand the action to second order around the classical path:
#
# $$S[\boldsymbol{x}_{\text{cl}} + \delta\boldsymbol{x}] = S[\boldsymbol{x}_{\text{cl}}] + \int \frac{\delta^2 S}{\delta\boldsymbol{x}^2} (\delta\boldsymbol{x})^2 \, \mathrm{d}t + \cdots$$
#
#
# The **second variation** $\delta^2 S/\delta\boldsymbol{x}^2$ is a differential operator (functional Hessian). For a particle in a potential $V(\boldsymbol{x})$:
#
# $$\frac{\delta^2 S}{\delta\boldsymbol{x}(t)^2} = -m\frac{\mathrm{d}^2}{dt^2} - V''(\boldsymbol{x}_{\text{cl}})$$
#
#
# The path integral over fluctuations $\delta\boldsymbol{x}$ becomes a **Gaussian functional integral**, which can be evaluated using the functional generalization of Gaussian integrals (related to the **functional determinant** or **path integral measure**).
#
# **Result**:
#
# $$K(\boldsymbol{x}_f, t_f; \boldsymbol{x}_i, t_i) \approx \mathrm{e}^{\mathrm{i}S_{\text{cl}}/\hbar} \sqrt{\frac{1}{\det(\delta^2 S/\delta\boldsymbol{x}^2)}} \times \text{(quantum correction factor)}$$
#
#
# The **phase** is determined by the classical action; the **amplitude correction** comes from quantum fluctuations. This is the essence of the **semiclassical approximation**.
#
# :::
#
# :::{admonition} Example: Particle in a Box
# :class: example
#
# For a free particle in a box (no potential), the classical action for a straight-line path from $\boldsymbol{x}_i$ to $\boldsymbol{x}_f$ in time $T$ is
#
# $$S_{\text{cl}} = \frac{m(\boldsymbol{x}_f - \boldsymbol{x}_i)^2}{2T}$$
#
#
# **For an electron** moving 1 cm in 1 second:
#
# $$S_{\text{cl}} \sim (10^{-30} \text{ kg})(0.01 \text{ m})^2/(1 \text{ s}) \sim 10^{-34} \text{ J·s}$$
#
#
# Compared to $\hbar \sim 10^{-34}$ J·s, we have $S_{\text{cl}} \sim \hbar$—quantum effects are important.
#
# **For a baseball** (1 kg) moving 1 m in 1 second:
#
# $$S_{\text{cl}} \sim (1)(1)^2/(1) \sim 1 \text{ J·s} = 10^{34} \hbar$$
#
#
# The classical action is enormous—the path integral is totally dominated by the single classical path. Quantum effects vanish. The ball follows Newton's laws.
# :::
#
# ### The Correspondence Principle
#
# The stationary phase analysis quantifies the **correspondence principle**: Quantum mechanics reduces to classical mechanics in the limit where $S \gg \hbar$ (i.e., macroscopic systems).
#
# | Regime | $S/\hbar$ | Behavior |
# |--------|-----------|----------|
# | Classical | $\gg 1$ | Single path dominates; classical trajectory |
# | Semiclassical | $\sim 1$ | Classical path + quantum fluctuations |
# | Quantum | $\lesssim 1$ | All paths contribute; wave-like behavior |
#
# ### Summary
#
# - **Stationary phase approximation**: Integrals with rapidly oscillating phase are dominated by points where the phase is stationary
# - **Classical path selection**: The path integral selects the classical path (where $\delta S = 0$) through constructive interference
# - **Destructive interference**: Paths far from the classical trajectory have rapidly varying action—their phases cancel
# - **Quantum fluctuations**: Fluctuations around the classical path have action $\sim \hbar$ and contribute quantum corrections
# - **Classical limit**: As $\hbar \to 0$ or $S \gg \hbar$, the coherent region shrinks and only the classical path survives
# - **Correspondence principle**: Quantum mechanics has classical mechanics as a limit; the transition is controlled by the ratio $S/\hbar$
#
# :::{admonition} See Also
# :class: seealso
#
# - **[3 2 3 Schrodinger Equation](3-2-3-schrodinger-equation.ipynb)**: Path integral foundation
# - **[3 3 2 Wkb Approximation](3-3-2-wkb-approximation.ipynb)**: WKB approximation via stationary phase
# - **[3 4 1 Wick Rotation](3-4-1-wick-rotation.ipynb)**: Analytic continuation in phase
# :::

# %% [markdown]
# ## Homework
#
# **1. Stationary Phase Integral (Conceptual)**
#
# Consider the integral $I = \int_{-\infty}^{\infty} \mathrm{e}^{\mathrm{i}\Phi(x)/\hbar} f(x) \, \mathrm{d}x$ where $\Phi(x) = x^2 + x^3$ and $f(x) = 1$.
#
# (a) Find all stationary points where $d\Phi/dx = 0$.
#
# (b) For which stationary point(s) is the second derivative $\Phi''(x_0)$ positive? Negative? Explain why the sign matters for the SPA.
#
# (c) For small $\hbar$, explain qualitatively why the sign of $\Phi''$ affects the phase of the resulting integral.
#
#
# **2. Gaussian Integral via SPA**
#
# Verify the stationary phase result for a pure Gaussian. Let $\Phi(x) = ax^2$ (with $a > 0$ real) and $f(x) = 1$.
#
# (a) Apply the SPA formula to compute $I = \int_{-\infty}^{\infty} \mathrm{e}^{\mathrm{i}ax^2/\hbar} dx$.
#
# (b) Compare with the exact Gaussian integral formula $\int_{-\infty}^{\infty} \mathrm{e}^{\mathrm{i}ax^2} dx = \sqrt{\pi/(ia)}$.
#
# (c) Show that the SPA result is **exact** in this case. Why does the approximation work perfectly?
#
#
# **3. Width of the Stationary Region**
#
# In the SPA, the main contribution comes from a region where the phase variation is $\sim \hbar$.
#
# (a) Use the condition $\Phi''(x - x_0)^2 \sim \hbar$ to estimate the width of the stationary region in terms of $\hbar$, $\Phi(x_0)$, and $\Phi''(x_0)$.
#
# (b) For a free particle path integral with action $S = mv^2 t / 2$ (where $v$ is velocity and $t$ is the time interval), estimate the width in position space. How does it depend on $\hbar$, $m$, $v$, and $t$?
#
# (c) For an electron and a baseball moving at the same velocity over the same time interval, which has a larger quantum uncertainty region? Explain physically.
#
#
# **4. Classical Path Dominance**
#
# Consider two paths in a simple 1D potential: the classical path $x_{\text{cl}}(t)$ and a neighboring path that differs by a small fixed displacement $\delta x$ at all times.
#
# (a) Explain why the action difference $\Delta S$ between these two paths depends on whether $\delta x$ is first-order or second-order in deviations from $x_{\text{cl}}$.
#
# (b) If $\delta x \sim 1$ (macroscopic), what is the approximate action difference $\Delta S$ in units of $\hbar$ for a macroscopic system (where $S/\hbar \gg 1$)?
#
# (c) Convert this action difference to a phase difference $\Delta\phi = \Delta S/\hbar$. Why does this lead to destructive interference?
#
# (d) What happens in the classical limit $\hbar \to 0$?
#
#
# **5. The Correspondence Principle in the Path Integral**
#
# Make a quantitative estimate using the correspondence principle.
#
# (a) For a particle of mass $m$ moving distance $d$ in time $t$, the classical action is $S \sim md^2/t$. Show that the ratio $S/\hbar$ is a dimensionless measure of how "classical" the system is.
#
# (b) For an electron ($m = 10^{-30}$ kg) moving 1 nm ($10^{-9}$ m) in 1 ns ($10^{-9}$ s), compute $S/\hbar$. Is this electron classical or quantum?
#
# (c) For a ball ($m = 0.1$ kg) moving 1 m in 1 s, compute $S/\hbar$. Comment on the result.
#
# (d) How would the electron's $S/\hbar$ change if it were confined to a region $\sim$ 0.1 nm and observed over time $\sim$ 0.1 ns? Does this favor quantum or classical behavior?
#
#
# **6. Second Variation of the Action**
#
# For a particle in a potential $V(x)$, the classical action is $S = \int_0^T \left[\frac{1}{2}m\dot{x}^2 - V(x)\right] dt$.
#
# (a) The second variation is $\delta^2 S / \delta x(t)^2 = -m d^2/dt^2 - V''(x_{\text{cl}})$. Explain what each term represents: the first involves kinetic energy, the second involves the potential curvature at the classical path.
#
# (b) For a harmonic oscillator, $V(x) = \frac{1}{2}m\omega^2 x^2$, show that $\delta^2 S / \delta x(t)^2 = -m(d^2/dt^2 + \omega^2)$.
#
# (c) Is this second-variation operator positive or negative definite? What does this tell you about the stability of the classical path to small perturbations?
#
#
# **7. Validity Conditions for SPA**
#
# A student wants to apply the SPA to compute $I = \int_{-\infty}^{\infty} \mathrm{e}^{\mathrm{i} x^4 / \hbar} \sin(x) \, \mathrm{d}x$.
#
# (a) Identify the stationary points of $\Phi(x) = x^4$.
#
# (b) Check the validity conditions: (i) Is there a clear, isolated stationary point? (ii) How large is $\Phi''(x_0)$? (iii) Is the amplitude $f(x) = \sin(x)$ slowly varying near the stationary point?
#
# (c) Should the SPA be trusted for this integral? Explain why or why not.
#
#
# **8. Destructive Interference (Qualitative Reasoning)**
#
# In the path integral, most paths give phase factors $\mathrm{e}^{\mathrm{i}S[\text{path}]/\hbar}$ that point in different directions in the complex plane.
#
# (a) Why do paths that are **far from** the classical path tend to have **very different** phases?
#
# (b) Sketch a phasor diagram for five paths: the classical path and two pairs of neighbors symmetrically displaced from it. Explain how the phasors for non-classical paths tend to cancel.
#
# (c) For a macroscopic object, how many distinct "orientations" of phasors (phase differences) occur among all possible paths? Why does this lead to nearly complete cancellation?
#
#
# **9. Semiclassical Propagator**
#
# The SPA gives the propagator as
#
# $$K(x_f, t_f; x_i, t_i) \approx \mathrm{e}^{\mathrm{i}S_{\text{cl}}/\hbar} \sqrt{\frac{1}{\det(\delta^2 S/\delta x^2)}}$$
#
#
# (a) The exponent $S_{\text{cl}}/\hbar$ oscillates rapidly as the final position $x_f$ changes. What physical phenomenon does this oscillation describe?
#
# (b) The prefactor $\sqrt{1/\det(\delta^2 S/\delta x^2)}$ is a smooth, slowly-varying function. What does it represent?
#
# (c) Why must both terms be included to correctly describe the quantum propagation near the classical path?
