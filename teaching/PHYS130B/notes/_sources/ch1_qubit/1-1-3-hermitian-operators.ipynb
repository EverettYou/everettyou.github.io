# %% [markdown]
# # 1.1.3 Hermitian Operators

# %% [markdown]
# :::{admonition} Prompts
# :class: tip
#
# - In classical mechanics, observables are just functions on phase space. Why does quantum mechanics require observables to be Hermitian *operators* rather than ordinary functions? What does Hermiticity buy us?
# - Compute the eigenvalues and eigenvectors of $\hat{\sigma}^x$ and $\hat{\sigma}^z$ by hand. Why do all Pauli matrices have eigenvalues $\pm 1$?
# - Prove that if $\hat{O}$ is Hermitian and $|\psi_1\rangle, |\psi_2\rangle$ are eigenvectors with different eigenvalues, then they are orthogonal. What goes wrong if the eigenvalues are equal?
# - For the state $|\psi\rangle = \frac{1}{\sqrt{3}}(|0\rangle + \sqrt{2}|1\rangle)$, compute $\langle \hat{\sigma}^z \rangle$ and $\langle \hat{\sigma}^x \rangle$ and interpret what these numbers mean physically.
# - The expectation value formula $\langle \hat{O} \rangle = \langle \psi | \hat{O} | \psi \rangle$ gives the average of many measurements. Is this the *same* as saying the expectation value equals the average outcome computed from the Born rule probabilities, or are these two different statements that happen to agree?
# :::

# %% [markdown]
# ## Lecture Notes
#
# Observation in quantum mechanics is not passive—it is fundamentally tied to the mathematical structure of reality through operators. To measure a physical quantity is to ask which values are possible, which states correspond to those values, and how certain we can be of the result. Hermitian operators encode this structure completely. They are the mathematical embodiment of our ability to know, predict, and control quantum systems, and understanding their properties is essential to understanding the bridge between theory and experiment.
#
# ### Observables as Hermitian Operators
#
# In quantum mechanics, a physical **observable** (measurable quantity) is represented by a **Hermitian operator** acting on the Hilbert space. This is one of the fundamental postulates of quantum mechanics.
#
# **Definition (Hermitian operator)**: An operator $\hat{O}$ is **Hermitian** (or **self-adjoint**) if
#
# $$
#
#
# \hat{O}^\dagger = \hat{O}
#
# $$ (eq-hermitian-def)
#
# where $\hat{O}^\dagger$ is the **Hermitian conjugate** (or **adjoint**), defined by the property
#
# $$
#
#
# \langle \psi | \hat{O} \phi \rangle = \langle \hat{O}^\dagger \psi | \phi \rangle
#
# $$ (eq-hermitian-conjugate-def)
#
# for all states $|\psi\rangle, |\phi\rangle$.
#
# ### Hermitian Conjugate and Matrix Form
#
# For a matrix $M$, the Hermitian conjugate is the **conjugate transpose**:
#
# $$
#
#
# M^\dagger = (M^*)^T = (M^T)^*
#
# $$ (eq-hermitian-conjugate-matrix)
#
# $$
#
#
# M = \begin{pmatrix} a & b \\ c & d \end{pmatrix},
#
# $$
#
#
# A matrix is Hermitian if $M = M^\dagger$. To compute the Hermitian conjugate:
#
# :::{admonition} Derivation: Hermitian Conjugate
# :class: dropdown note
#
# $$
#
#
# M^\dagger = \begin{pmatrix} a^* & c^* \\ b^* & d^* \end{pmatrix}.
#
# $$
#
#
# For Hermiticity, we need $M = M^\dagger$, which requires:
# - Diagonal elements are **real**: $a, d \in \mathbb{R}$
# - Off-diagonal elements are **conjugate pairs**: $b = c^*$
# :::
#
# Hermitian operators have the crucial property that their **eigenvalues are real**. Since measurement outcomes are real numbers (we observe real values on our instruments), the operators representing observables must be Hermitian. This is not just convenience—it's a requirement for quantum mechanics to be physically sensible.
#
# :::{admonition} Discussion
# :class: dropdown warning
#
# **Can we measure any operator? Construct a Hermitian operator and determine if it corresponds to a physical observable.**
#
# Suppose you construct the operator $\hat{M} = \begin{pmatrix} 1 & 0 \\ 0 & 2 \end{pmatrix}$ (a diagonal matrix with distinct real eigenvalues 1 and 2). Is $\hat{M}$ Hermitian? Can you measure $\hat{M}$ on a qubit?
#
# Now consider a more subtle case: in a two-level atom with ground state $|g\rangle$ and excited state $|e\rangle$, define $\hat{A} = |g\rangle\langle e|$ (the lowering operator). Compute $\hat{A}^\dagger$ and check if $\hat{A}$ is Hermitian. What *is* $\hat{A}^\dagger \hat{A}$ and $\hat{A} \hat{A}^\dagger$? These non-Hermitian operators are still useful in quantum mechanics for describing *transitions*.
#
# **Your task**: Explain why we restrict measurements to Hermitian observables (hint: think about eigenvalues). Then show that $\hat{N} = \hat{A}^\dagger \hat{A}$ is Hermitian and has non-negative eigenvalues. What physical quantity does $\hat{N}$ represent in an atom?
#
# :::
#
# ### Eigenvalues and Eigenvectors
#
# For a linear operator $\hat{O}$ acting on a state $|\psi\rangle$, there may exist special states (eigenstates) that are only **rescaled** by the operator:
#
# **Eigenvalue equation**:
#
# $$
#
#
# \hat{O} |\psi\rangle = \lambda |\psi\rangle
#
# $$ (eq-eigenvalue-equation)
#
# where:
# - $|\psi\rangle$ is an **eigenvector** (or **eigenstate**)
# - $\lambda$ is the **eigenvalue**, a number (generally complex) that scales the eigenvector
#
# #### Properties of Hermitian Operators
#
# :::{admonition} Theorem: Properties of Hermitian
# :class: important
#
# Let $\hat{O}$ be a Hermitian operator. Then:
#
# 1. **Eigenvalues are real**: If $\hat{O}|\psi\rangle = \lambda|\psi\rangle$ with $\hat{O}^\dagger = \hat{O}$, then $\lambda \in \mathbb{R}$.
#
# :::{admonition} Proof: Eigenvalues are Real
# :class: dropdown note
#
# Take the inner product of the eigenvalue equation with $\langle\psi|$:
#
# $$\langle\psi|\hat{O}|\psi\rangle = \lambda \langle\psi|\psi\rangle = \lambda.$$
#
#
# Taking the complex conjugate:
#
# $$\langle\psi|\hat{O}|\psi\rangle^* = \lambda^*.$$
#
#
# But also:
#
# $$\langle\psi|\hat{O}|\psi\rangle^* = \langle\psi|\hat{O}^\dagger|\psi\rangle = \langle\psi|\hat{O}|\psi\rangle = \lambda$$
#
#
# (using Hermiticity and the fact that $\langle\psi|\hat{O}|\psi\rangle$ is a number). Thus $\lambda = \lambda^*$, so $\lambda \in \mathbb{R}$. ✓
# :::
#
# 2. **Eigenvectors are orthogonal** (for distinct eigenvalues): If $\hat{O}|\psi_1\rangle = \lambda_1|\psi_1\rangle$ and $\hat{O}|\psi_2\rangle = \lambda_2|\psi_2\rangle$ with $\lambda_1 \neq \lambda_2$, then $\langle\psi_1|\psi_2\rangle = 0$.
#
# :::{admonition} Proof: Eigenvectors are Orthogonal
# :class: dropdown note
#
# $$\langle\psi_1|\hat{O}|\psi_2\rangle = \lambda_2 \langle\psi_1|\psi_2\rangle.$$
#
#
# Also:
#
# $$\langle\psi_1|\hat{O}|\psi_2\rangle = (\hat{O}|\psi_1\rangle)^\dagger|\psi_2\rangle = (\lambda_1|\psi_1\rangle)^\dagger|\psi_2\rangle = \lambda_1^* \langle\psi_1|\psi_2\rangle = \lambda_1 \langle\psi_1|\psi_2\rangle$$
#
#
# (since $\lambda_1$ is real for Hermitian operators). Thus:
#
# $$\lambda_2 \langle\psi_1|\psi_2\rangle = \lambda_1 \langle\psi_1|\psi_2\rangle \implies (\lambda_2 - \lambda_1)\langle\psi_1|\psi_2\rangle = 0.$$
#
#
# Since $\lambda_1 \neq \lambda_2$, we have $\langle\psi_1|\psi_2\rangle = 0$. ✓
# :::
#
# :::
#
# 3. **Completeness**: For a 2-dimensional system (like a qubit), there are at most **two linearly independent eigenvectors**. These span the entire Hilbert space and form a **basis** (the **eigenbasis** of the operator).
#
# :::{admonition} Discussion
# :class: dropdown warning
#
# **Beyond finite dimensions: when is Hermitian different from self-adjoint?**
#
# In finite dimensions, "Hermitian" and "self-adjoint" are equivalent, and completeness is guaranteed. But in infinite-dimensional Hilbert spaces (like position and momentum operators on $\mathbb{R}$), these concepts differ subtly. A Hermitian operator may not be self-adjoint if its domain (the set of states it acts on) is not chosen carefully.
#
# For example, the position operator $\hat{x}$ defined on the space of all smooth functions with compact support is Hermitian—but is it self-adjoint? One answer is "yes if we allow distributions." Another is "only with boundary conditions."
#
# **Your task**:
#
# (a) State the formal definition of a self-adjoint operator: $\hat{O}$ is self-adjoint if $\hat{O}^\dagger = \hat{O}$ *and* the domain of $\hat{O}$ equals the domain of $\hat{O}^\dagger$. Why does domain matter?
#
# (b) For a particle in a box with infinite walls, the momentum operator $\hat{p}$ acting on smooth functions that vanish at the walls is Hermitian. Is it self-adjoint? Why or why not?
#
# (c) Does the distinction between Hermitian and self-adjoint affect physical predictions? That is, do eigenvalues and orthogonality of eigenvectors still hold? Or can domain pathologies lead to unexpected measurement outcomes?
#
# :::
#
# ### The Pauli Matrices
#
# The most important Hermitian operators for a qubit are the **Pauli matrices**, representing spin along three orthogonal directions:
#
# $$
#
#
# \hat{\sigma}^x = \begin{pmatrix} 0 & 1 \\ 1 & 0 \end{pmatrix}, \quad
# \hat{\sigma}^y = \begin{pmatrix} 0 & -\mathrm{i} \\ i & 0 \end{pmatrix}, \quad
# \hat{\sigma}^z = \begin{pmatrix} 1 & 0 \\ 0 & -1 \end{pmatrix}
#
# $$ (eq-pauli-matrices)
#
# All three are Hermitian ($\hat{\sigma}^i = (\hat{\sigma}^i)^\dagger$) with eigenvalues $\pm 1$.
#
# The Pauli matrices satisfy the algebra:
#
# $$
#
#
# [\hat{\sigma}^i, \hat{\sigma}^j] = 2\mathrm{i}\epsilon_{ijk}\hat{\sigma}^k
#
# $$
#
#
# where $\epsilon_{ijk}$ is the Levi-Civita symbol. A detailed exploration of Pauli algebra, spin representations, and commutation relations is the focus of **§2.2 in Chapter 2**.
#
# ### Expectation Values
#
# For a quantum state $|\psi\rangle$ and an observable $\hat{O}$, the **expectation value** (or **mean value**) is
#
# $$
#
#
# \langle \hat{O} \rangle = \langle \psi | \hat{O} | \psi \rangle
#
# $$ (eq-expectation-value)
#
# **Properties**:
# - For a Hermitian operator, $\langle \hat{O} \rangle$ is **real** (automatically).
# - It represents the **average outcome** if we measure $\hat{O}$ on many identically prepared states.
#
# For the state $|\psi\rangle = \frac{1}{\sqrt{2}}(|0\rangle + |1\rangle)$ and observable $\hat{\sigma}^z$:
#
# :::{admonition} Calculation: Expectation Value
# :class: dropdown note
#
# $$
#
#
# \langle \hat{\sigma}^z \rangle = \frac{1}{2}(\langle 0| + \langle 1|) \begin{pmatrix} 1 & 0 \\ 0 & -1 \end{pmatrix} \frac{1}{\sqrt{2}}(|0\rangle + |1\rangle)
#
# $$
#
#
# $$
#
# = \frac{1}{2}(\langle 0| + \langle 1|)\frac{1}{\sqrt{2}}(|0\rangle - |1\rangle) = \frac{1}{2\sqrt{2}}(1 - 1) = 0
#
# $$
#
#
# :::
#
# This makes physical sense: the state is an equal superposition of spin-up and spin-down along z, so the average z-spin is zero.
#
# ### The Measurement Postulate
#
# **Postulate (Measurement)**: When we measure an observable $\hat{O}$ on a system in state $|\psi\rangle$:
#
# 1. **Possible outcomes**: The measurement result is an eigenvalue $\lambda_i$ of $\hat{O}$.
# 2. **Probability**: The probability of obtaining outcome $\lambda_i$ is
#
#    $$
#
#
#    P_i = |\langle \psi_i | \psi \rangle|^2
#
#    $$ (eq-measurement-probability)
#
#    where $|\psi_i\rangle$ is the normalized eigenvector corresponding to eigenvalue $\lambda_i$.
# 3. **State collapse**: After the measurement, the state **collapses** to the eigenstate $|\psi_i\rangle$ corresponding to the observed outcome.
#
# :::{admonition} Discussion
# :class: dropdown warning
#
# **Measurement vs. evolution: at what point does collapse occur?**
#
# In quantum mechanics, the system evolves via the Schrödinger equation $\hat{H}|\psi\rangle$ when left alone. But measuring the system is just another interaction—we apply a Hamiltonian and evolve. At what point does an interaction qualify as a "measurement"?
#
# Consider a photon entering a detector:
#
# - Before photon enters: state $|\psi\rangle$ (in superposition of being absorbed or reflected).
# - Photon interacts with detector atoms via electromagnetic coupling (a Hamiltonian interaction).
# - After $\sim 1~\mu\text{s}$ of evolution: detector is "entangled" with photon. The photon state is now correlated with many detector atoms.
# - After $\sim 1~\text{ms}$: heat from absorption has spread to $10^{23}$ atoms. Reversing the interaction to recover the original superposition is thermodynamically impossible.
#
# **Your task**:
#
# (a) Is the interaction itself a measurement? Or does measurement occur only when the environment gets involved and makes reversing the interaction impossible?
#
# (b) The **Quantum Zeno Effect** shows that rapid measurements suppress transitions. If you measure every $\Delta t = 10^{-9}~\text{s}$, you freeze the system. But if no single measurement is "special," and each is just unitary evolution, how does frequent *evolution* prevent *further* evolution? Does this scenario resolve the question of whether collapse is real or just an update rule?
#
# (c) Propose a physical, observer-independent definition of when "measurement" occurs. What role does irreversibility play?
#
# :::
#
# #### Average Outcome
#
# The **expectation value** is the average of all possible outcomes weighted by their probabilities:
#
# $$
#
#
# \langle \hat{O} \rangle = \sum_i \lambda_i P_i = \sum_i \lambda_i |\langle \psi_i | \psi \rangle|^2
#
# $$ (eq-expectation-as-sum)
#
# This is consistent with the definition $\langle \hat{O} \rangle = \langle \psi | \hat{O} | \psi \rangle$.
#
# ### Spectral Decomposition
#
# Any Hermitian operator can be decomposed in terms of its eigenvalues and eigenprojectors:
#
# $$
#
#
# \hat{O} = \sum_i \lambda_i |\psi_i\rangle\langle\psi_i|
#
# $$ (eq-spectral-decomposition)
#
# where $|\psi_i\rangle\langle\psi_i|$ is the **projector** onto the eigenstate $|\psi_i\rangle$.
#
#
# :::{admonition} Example: Spectral Decomposition
# :class: dropdown note
#
# For $\hat{\sigma}^z$ with eigenstates $|0\rangle, |1\rangle$ (eigenvalues $\pm 1$):
#
# $$
#
#
# \hat{\sigma}^z = (+1)|0\rangle\langle 0| + (-1)|1\rangle\langle 1| = \begin{pmatrix} 1 & 0 \\ 0 & 0 \end{pmatrix} - \begin{pmatrix} 0 & 0 \\ 0 & 1 \end{pmatrix} = \begin{pmatrix} 1 & 0 \\ 0 & -1 \end{pmatrix} \quad \checkmark
#
# $$
#
#
# For $\hat{\sigma}^x$ with eigenstates $|+\rangle = \frac{1}{\sqrt{2}}(|0\rangle + |1\rangle)$ and $|-\rangle = \frac{1}{\sqrt{2}}(|0\rangle - |1\rangle)$ (eigenvalues $\pm 1$):
#
# $$
#
#
# \hat{\sigma}^x = (+1)|+\rangle\langle +| + (-1)|-\rangle\langle -| = \frac{1}{2}\begin{pmatrix} 1 & 1 \\ 1 & 1 \end{pmatrix} - \frac{1}{2}\begin{pmatrix} 1 & -1 \\ -1 & 1 \end{pmatrix} = \begin{pmatrix} 0 & 1 \\ 1 & 0 \end{pmatrix} \quad \checkmark
#
# $$
#
#
# For $\hat{\sigma}^y$ with eigenstates $|\mathrm{i}\rangle = \frac{1}{\sqrt{2}}(|0\rangle + \mathrm{i}|1\rangle)$ and $|\bar{\mathrm{i}}\rangle = \frac{1}{\sqrt{2}}(|0\rangle - \mathrm{i}|1\rangle)$ (eigenvalues $\pm 1$):
#
# $$
#
#
# \hat{\sigma}^y = (+1)|\mathrm{i}\rangle\langle \mathrm{i}| + (-1)|\bar{\mathrm{i}}\rangle\langle \bar{\mathrm{i}}| = \frac{1}{2}\begin{pmatrix} 1 & -\mathrm{i} \\ \mathrm{i} & 1 \end{pmatrix} - \frac{1}{2}\begin{pmatrix} 1 & \mathrm{i} \\ -\mathrm{i} & 1 \end{pmatrix} = \begin{pmatrix} 0 & -\mathrm{i} \\ \mathrm{i} & 0 \end{pmatrix} \quad \checkmark
#
# $$
#
#
# :::
#
# :::{admonition} Key Result: Measurement and Expectation
# :class: important
#
# The expectation value $\langle \hat{O} \rangle = \langle \psi | \hat{O} | \psi \rangle$ is:
# - The **average result** of many measurements on identically prepared states.
# - Computable as a **sum of eigenvalues weighted by probabilities**.
# - A **real number** (when $\hat{O}$ is Hermitian).
# - The **one number that characterizes the state's response to measurement** of that observable.
# :::
#
# ### Summary
#
# - **Observables** are represented by **Hermitian operators**, which have real eigenvalues and orthogonal eigenvectors.
# - The **Pauli matrices** $\hat{\sigma}^x, \hat{\sigma}^y, \hat{\sigma}^z$ are the fundamental observables for a qubit, representing spin along the three axes.
# - **Eigenvalues** are the possible measurement outcomes; **eigenvectors** are the states with definite outcomes.
# - **The measurement postulate** connects theory to experiment: measurement outcomes are eigenvalues, with probabilities given by the Born rule.
# - **Expectation values** are averages of measurement outcomes and are computed as $\langle \hat{O} \rangle = \langle \psi | \hat{O} | \psi \rangle$.
#
# :::{admonition} See Also
# :class: seealso
#
# - **[1.1.1 Spins and Qubits](1-1-1-spins-and-qubits.ipynb)**: The Pauli matrices are concrete Hermitian operators for spin
# - **[1.2.1 Measurement Postulate](1-2-1-measurement-postulate.ipynb)**: Hermitian operators represent physical observables; their eigenstates are measurement outcomes
# - **[2.2.1 Angular Momentum Algebra](../ch2_identical-particles/2-2-1-angular-momentum-algebra.ipynb)**: Angular momentum operators are prime examples of Hermitian operators with rich algebraic structure
# :::

# %% [markdown]
# ## Homework
#
# **1.** Show that the Pauli matrix $\hat{\sigma}^y = \begin{pmatrix} 0 & -\mathrm{i} \\ i & 0 \end{pmatrix}$ is Hermitian by explicitly computing $(\hat{\sigma}^y)^\dagger$ and verifying it equals $\hat{\sigma}^y$. Then find its eigenvalues and normalized eigenvectors.
#
# **2.** Consider the operator $\hat{A} = \begin{pmatrix} 1 & \mathrm{i} \\ i & 1 \end{pmatrix}$. Is $\hat{A}$ Hermitian? If not, find $\hat{A}^\dagger$ and construct a Hermitian operator from $\hat{A}$ using the combination $\frac{1}{2}(\hat{A} + \hat{A}^\dagger)$.
#
# **3.** A qubit is in the state $|\psi\rangle = \frac{1}{\sqrt{3}}|0\rangle + \sqrt{\frac{2}{3}}|1\rangle$. Compute the expectation values $\langle\hat{\sigma}^x\rangle$, $\langle\hat{\sigma}^y\rangle$, and $\langle\hat{\sigma}^z\rangle$. Verify that $\langle\hat{\sigma}^x\rangle^2 + \langle\hat{\sigma}^y\rangle^2 + \langle\hat{\sigma}^z\rangle^2 = 1$.
#
# **4.** The spectral decomposition of $\hat{\sigma}^x$ is $\hat{\sigma}^x = (+1)|+\rangle\langle+| + (-1)|-\rangle\langle-|$, where $|+\rangle = \frac{1}{\sqrt{2}}(|0\rangle + |1\rangle)$ and $|-\rangle = \frac{1}{\sqrt{2}}(|0\rangle - |1\rangle)$. Verify this by explicitly computing the right-hand side as a $2\times 2$ matrix.
#
# **5.** Show that the eigenvalues of any projector $\hat{P} = |\psi\rangle\langle\psi|$ are 0 and 1. What are the corresponding eigenstates? Is a projector Hermitian?
#
# **6.** A spin-1/2 particle is in the state $|\psi\rangle = \cos\alpha\,|\uparrow\rangle + \sin\alpha\,|\downarrow\rangle$ (with $\alpha$ real). You measure $\hat{\sigma}^z$. What are the possible outcomes and their probabilities? Then compute $\langle\hat{\sigma}^z\rangle$ directly from the definition $\langle\psi|\hat{\sigma}^z|\psi\rangle$ and verify it equals $\sum_i \lambda_i P_i$.
#
# **7.** The operator $\hat{n}\cdot\hat{\boldsymbol{\sigma}} = n_x \hat{\sigma}^x + n_y \hat{\sigma}^y + n_z \hat{\sigma}^z$ represents spin along an arbitrary unit vector $\hat{n} = (n_x, n_y, n_z)$ with $|\hat{n}| = 1$. Show that $(\hat{n}\cdot\hat{\boldsymbol{\sigma}})^2 = \hat{I}$ (the identity matrix). What does this imply about the eigenvalues of $\hat{n}\cdot\hat{\boldsymbol{\sigma}}$?
#
# **8.** Using the result of Problem 7, show that the eigenvalues of $\hat{n}\cdot\hat{\boldsymbol{\sigma}}$ are $\pm 1$ for any unit vector $\hat{n}$. Find the eigenvector corresponding to eigenvalue $+1$ for the case $\hat{n} = (\sin\theta, 0, \cos\theta)$ (a vector in the $xz$-plane). Express your answer in terms of $\theta$.
#
# **9.** Prove that the expectation value of any Hermitian operator $\hat{O}$ is real-valued for any state $|\psi\rangle$. That is, show $\langle\hat{O}\rangle^* = \langle\hat{O}\rangle$ using the definition $\langle\hat{O}\rangle = \langle\psi|\hat{O}|\psi\rangle$ and the Hermiticity condition.
